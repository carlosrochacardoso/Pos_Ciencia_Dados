# %%
import pandas as pd
from pymongo import MongoClient
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

from nltk.tokenize import TweetTokenizer

import tweepy
import time

from string import punctuation
from bson import json_util, ObjectId
from pandas.io.json import json_normalize
import json
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth',300)

APP_KEY="xLOajxwsYIf0vcDEJZDia25Ob"
APP_SECRET="z9K2L8e6BbVV6eUY05apuEWTqqCTse6rCOxWqX2Nb1aA2eeI9d"
OAUTH_TOKEN="30895751-9ZFWSUilQpeNc6trGdShEEErOdDtLfSM8W35rUsZa"
OAUTH_TOKEN_SECRET="gFzdNSa7tDr732PuTaHugkNjh1YKyrMua6Xi9h1ikshq4"

# %%
def mongo_to_dataframe(mongo_data):

        sanitized = json.loads(json_util.dumps(mongo_data))
        normalized = json_normalize(sanitized)
        df = pd.DataFrame(normalized)

        return df

# %% [markdown]
# # Carga dos dados

# %% [markdown]
# ## Consulta aos Tweets salvos no Mongo

# %% [markdown]
# Conexão e consulta dos tweets salvos mongodb a partir da coleta via streming utilizando o Apache NiFi. Carga dos dados no pandas dataframe.

# %%
host = '172.17.0.3'
port = 27017
collection = 'cemig'
db_name = 'cemig'
collection = 'raw_tweets'
collection_rt = 'raw_retweets'

conn = MongoClient(host, port)
db = conn[db_name]
cursor = db[collection].find({},{"_id":0,"id":1,"retweeted":1,"timestamp_ms":1,"text":1,'user.screen_name':1,'user.location':1,'user.followers_count':1,'user.friends_count':1})
df_tweets =  mongo_to_dataframe(cursor)

# %%
df_tweets["tempo"] = pd.to_datetime(df_tweets['timestamp_ms'], unit='ms').dt.tz_localize('America/Sao_Paulo')
df_tweets["data"] = df_tweets["tempo"].dt.date
df_tweets["text"] = df_tweets["text"].str.replace('https:\/\/.*\s?','')

df_tweets.head()
# Out:
#                     id  retweeted  \
# 0  1107042314097229824      False
# 1  1107052443580420096      False
# 2  1107053694523228160      False
# 3  1107072220281688064      False
# 4  1107098836516962305      False
#
#                                                   text   timestamp_ms  \
# 0              CEMIG ta vacilona hoje em, assim não dá  1552774430189
# 1              Ficar sem luz e foda essa loja da Cemig  1552776845246
# 2                      Cemig zuando os pratence hihihi  1552777143494
# 3              @BETHEVITAS @mxrcone CEMIG curtiu isso.  1552781560379
# 4  Recado dos Eletricitários em defesa da CEMIG - FNU   1552787906184
#
#    user.followers_count  user.friends_count                 user.location  \
# 0                   507                 423          Minas Gerais, Brasil
# 1                   152                 344  Governador Valadares, Brasil
# 2                   382                 295                ciúmentolandia
# 3                  1461                1466          Minas Gerais, Brasil
# 4                    63                1697       Rio de Janeiro - Brasil
#
#   user.screen_name                            tempo        data
# 0        MeloSahra 2019-03-16 22:13:50.189000-03:00  2019-03-16
# 1      R_Freitas21 2019-03-16 22:54:05.246000-03:00  2019-03-16
# 2        sou_geise 2019-03-16 22:59:03.494000-03:00  2019-03-16
# 3         jkbrunno 2019-03-17 00:12:40.379000-03:00  2019-03-17
# 4            magu5 2019-03-17 01:58:26.184000-03:00  2019-03-17

# %% [markdown]
# ## Carga do Dicionário de Palavras e Polaridade

# %% [markdown]
# Carga e parse do arquivo contendo palavras e polaridades
# Criação de um dicionário contendo palavra e polaridade

# %%
df_arq = pd.read_csv('SentiLex-PT02/SentiLex-flex-PT02.txt', header=None, names=['col'], sep='#')
df_arq = df_arq[~df_arq.col.str.contains("IDIOM")]

df_sentilex = df_arq.col.str.extract(r'^(?P<palavra>.*),.*\.PoS.*=(?P<polaridade>.?[0-9]);ANOT', expand=True)
df_sentilex = pd.Series(df_sentilex.polaridade.values,index=df_sentilex.palavra).to_dict()

# %% [markdown]
# ## Coletando os retweets

# %%
auth = tweepy.OAuthHandler(APP_KEY,APP_SECRET)
auth.set_access_token(OAUTH_TOKEN,OAUTH_TOKEN_SECRET)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
for index, row in df_tweets.iterrows():
    try:
        rset = api.retweets(row['id'])
    except tweepy.TweepError as e:
        print(e)
        print(row['id'])
        print()
    
    if len(rset) > 0:
        rt_json = rset[0]._json
        
        try:
            db[collection_rt].insert_one(rt_json)
            print(row['id'])
        except pymongo.errors.PyMongoError as e: 
            print(e)
            print(row['id'])
            print()
# Out:
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# 1107115671501053952
#
# 1107168427398053888
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# 1107273920279990273
#
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# 1107338090975236097
#
# 1107378895752495107
# 1107379441611784192
# 1107382489834758152
# 1107385285111881729
# 1107417158668247040
# 1107418363565883393
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# 1107423094317166601
#
# [{'code': 200, 'message': 'Forbidden.'}]
# 1107448658088337408
#
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# 1107451945265049600

# %% [markdown]
# ## Criando DataFrame com os tokens extraídos dos Tweets

# %%
df_tokens = pd.DataFrame()

for index, row in df_tweets.iterrows():
    palavras = word_tokenize(row['text'].lower())
    sw = set(stopwords.words('portuguese') + list(punctuation) + list(['cemig','…','¿','...','-…','https','rt','pra','r','é','tá']))
    
    df_token_tmp = pd.DataFrame()
    df_token_tmp["tokens"] = [palavra for palavra in palavras if palavra not in sw]
    df_token_tmp["id"] = row['id']
    df_token_tmp["polaridade"] = df_token_tmp["tokens"].apply(df_sentilex.get)
    
    #print(df_token_tmp)
    df_tokens = df_tokens.append(df_token_tmp, ignore_index=True)
#    df_token_tmp["tokens"] = 
#    df_tokens["id"] = row['id']
        
df_tweets_tokens = df_tokens.set_index('id').join(df_tweets.set_index('id'))
df_tweets_tokens

# %% [markdown]
# # Análise dos Dados

# %% [markdown]
# ## Distribuição dos Tweets por dia

# %%
ax = sns.countplot(x="data", data=df_tweets)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Contagem de frequência das palavras

# %% [markdown]
# Listando as 10 mais frequentes

# %%
df_tweets_tokens.groupby('tokens').tokens.count().nlargest(10)
# Out:
# tokens
# energia          61
# luz              60
# cmig4            54
# cmig-n1          49
# mil              39
# renova           37
# camarote         36
# romeuzema        33
# anos             32
# independência    31
# Name: tokens, dtype: int64

# %% [markdown]
# ## Nuvem das palavras mais frequentes

# %%
texto_cloud = ' '.join(df_tweets_tokens.tokens)

wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(texto_cloud) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# ## CMIG4: Avaliando a ocorrência da palavra

# %%
df_cmig4 = df_tweets_tokens[['text']].loc[df_tweets_tokens['tokens'] == 'cmig4']
df_cmig4.head(5)

# %%
ax = sns.countplot(x="data", data=df_cmig4)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# O termo refere-se ao código do papel CEMIG negociado na bolsa de valores. Conforme observado na lista de tweets e data de propagação, tem relação com o informe de fato relevante encaminhado pela CEMIG ao mercado de ações.

# %% [markdown]
# ## CAMAROTE: Avaliando a ocorrência palavra

# %%
df_camarote = df_tweets_tokens[['text','user.screen_name','data']].loc[df_tweets_tokens['tokens'] == 'camarote']
df_camarote.head(5)
# Out:
#                                                                                                                                                               text  \
# id
# 1109215677053837313                   Cemig pagou R$ 990 mil por 3 anos de camarote no Independência; no Mineirão, preço seria R$ 390 mil\nhttps://t.co/QjdpFL4TF3
# 1109215897464512515  RT @jornalhojeemdia: Cemig pagou R$ 990 mil por 3 anos de camarote no Independência; no Mineirão, preço seria R$ 390 mil\nhttps://t.co/QjdpF…
# 1109216983755698176  RT @jornalhojeemdia: Cemig pagou R$ 990 mil por 3 anos de camarote no Independência; no Mineirão, preço seria R$ 390 mil\nhttps://t.co/QjdpF…
# 1109217168451883009  RT @jornalhojeemdia: Cemig pagou R$ 990 mil por 3 anos de camarote no Independência; no Mineirão, preço seria R$ 390 mil\nhttps://t.co/QjdpF…
# 1109218880659079170  RT @jornalhojeemdia: Cemig pagou R$ 990 mil por 3 anos de camarote no Independência; no Mineirão, preço seria R$ 390 mil\nhttps://t.co/QjdpF…
#
#                     user.screen_name        data
# id
# 1109215677053837313  jornalhojeemdia  2019-03-22
# 1109215897464512515  REGINALDOGALO10  2019-03-22
# 1109216983755698176         digaormf  2019-03-22
# 1109217168451883009       rafael_fr2  2019-03-22
# 1109218880659079170       sracansada  2019-03-22

# %%
ax = sns.countplot(x="data", data=df_camarote)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# O termo tem relação com notícia veiculada pelo jornal Hoje em Dia, propagada entre os dias 22 e 24 de março. Segundo o jornal, a CEMIG teria pago o valor de 990 mil por 3 anos de camarote no estádio independência. Ainda segundo o jornal, o mesmo serviço poderia ter sido contratado no Minerião pelo valor de 390 mil.
#
# Podemos observar que outros termos que aparecem na lista dos mais frequentes tem relação com esse mesmo fato: [mil, independência].

# %% [markdown]
# ## Contagem de frequência das palavras com polaridade Negativa

# %% [markdown]
# Listando as 10 mais frequentes

# %%
df_tweets_tokens_neg = df_tweets_tokens.loc[df_tweets_tokens['polaridade'] == '-1']
df_tweets_tokens_neg.groupby('tokens').tokens.count().nlargest(10)
# Out:
# tokens
# venda       23
# apaga       14
# odeio       12
# estranho    10
# pisca        6
# apagava      5
# caiu         5
# derrotas     5
# falta        5
# vender       5
# Name: tokens, dtype: int64

# %% [markdown]
# ## Nuvem das palavras mais frequentes com polaridade negativa

# %%
texto_cloud = ' '.join(df_tweets_tokens_neg.tokens)

wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(texto_cloud) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# ## VENDA: Avaliando a ocorrência palavra

# %%
df_venda = df_tweets_tokens_neg[['text','data']].loc[df_tweets_tokens_neg['tokens'] == 'venda']
df_venda.head(5)
# Out:
#                                                                                                                                                              text  \
# id
# 1107123548622123008                      @joaoamoedonovo até agora nada do "novo" ter anunciado a venda das 2 estatais CEMIG E COPASA, que estão oprimindo o povo
# 1107656184926998528      Vejam o péssimo atendimento da Cemig, 20 minutos para pegar uma senha de atendimento, na Agência de Venda Nova!… https://t.co/6vovHDYfhG
# 1107657455771758592  RT @renato_artur: Vejam o péssimo atendimento da Cemig, 20 minutos para pegar uma senha de atendimento, na Agência de Venda Nova!#CEMIG htt…
# 1109060826328166400                                   Conselho da Cemig GT aprova compra de fatia na Renova e venda de Alto Sertão III -  https://t.co/RXJF6pPJnX
# 1109061194986459136                                   Conselho da Cemig GT aprova compra de fatia na Renova e venda de Alto Sertão III -  https://t.co/wd7qKr63Ls
#
#                            data
# id
# 1107123548622123008  2019-03-17
# 1107656184926998528  2019-03-18
# 1107657455771758592  2019-03-18
# 1109060826328166400  2019-03-22
# 1109061194986459136  2019-03-22

# %%
ax = sns.countplot(x="data", data=df_venda)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# A alta ocorrência do termo tem relação com dois fatos. O primeiro é a informação propagada no dia 22/03, de compra por parte da CEMIG de fatia da empresa Renova, e **venda** do complexo eólico de Alto Sertão III. Esse fato está relacionado ao comunicado enviado pela empresa ao mercado, no mesmo dia 22/03, razão da grande ocorrência do termo CMIG4, avaliado anteriormente.
#
# Outra razão para alta ocorrência do termo tem origem nos tweets propagados no dia 24/03, relacionados à notícia de que a CEMIG está vendendo alguns de seus imóveis, e a reação de usuários à essa notícia, pedindo que o governador Romeu Zema aproveite a ocasião para vender (ou privatizar) a empresa.

# %%
df_apaga = df_tweets_tokens_neg[['text','data']].loc[df_tweets_tokens_neg['tokens'] == 'apaga']
df_apaga.head(5)
# Out:
#                                                                                                                                                              text  \
# id
# 1107133154068971521  @BellaMoreira8 e a minha que tá o dia todo “apaga a luz e deixa o tempo passar BABY VOCÊ NÃO PERDE POR ESPERAR APAG… https://t.co/hgpPs1yCc8
# 1107417138879438849                          Cemig, se for pra piscar a luz de 10 em 10s apaga essa porra logo caralho\n\nPelo menos não queima o resto do meu PC
# 1107828522687565824                                                       Luz Aq de casa tá acende apaga acende apaga. Decide logo se vai ter apagão ou não cemig
# 1107828522687565824                                                       Luz Aq de casa tá acende apaga acende apaga. Decide logo se vai ter apagão ou não cemig
# 1109210554269384705  O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual… https://t.co/HAdoWxfOIw
#
#                            data
# id
# 1107133154068971521  2019-03-17
# 1107417138879438849  2019-03-17
# 1107828522687565824  2019-03-19
# 1107828522687565824  2019-03-19
# 1109210554269384705  2019-03-22

# %%
ax = sns.countplot(x="data", data=df_apaga)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
df_estranho = df_tweets_tokens_neg[['text','data']].loc[df_tweets_tokens_neg['tokens'] == 'estranho']
df_estranho.head(5)
# Out:
#                                                                                                                                                              text  \
# id
# 1109210554269384705  O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual… https://t.co/HAdoWxfOIw
# 1109210645096996867  RT @oalexsimoes: O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual govern…
# 1109211591860514816  RT @oalexsimoes: O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual govern…
# 1109212636061810688  RT @oalexsimoes: O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual govern…
# 1109215638982180865  RT @oalexsimoes: O cancelamento, há apenas uma semana, não apaga a necessidade de explicações. Muito estranho!!!! Pelo menos o atual govern…
#
#                            data
# id
# 1109210554269384705  2019-03-22
# 1109210645096996867  2019-03-22
# 1109211591860514816  2019-03-22
# 1109212636061810688  2019-03-22
# 1109215638982180865  2019-03-22

# %%
ax = sns.countplot(x="data", data=df_estranho)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
df_tweets_tokens_pos = df_tweets_tokens.loc[df_tweets_tokens['polaridade'] == '1']
df_tweets_tokens_pos.groupby('tokens').tokens.count().nlargest(10)
# Out:
# tokens
# energia       63
# relevante     21
# apaga         14
# belo          10
# bem            8
# apagava        5
# derrotas       5
# boa            3
# certíssimo     3
# eficiente      3
# Name: tokens, dtype: int64

# %%
df_energia = df_tweets_tokens_pos[['text','data']].loc[df_tweets_tokens_pos['tokens'] == 'energia']

df_energia.head(5)
# Out:
#                                                                                                                                                              text  \
# id
# 1107125367767207936  CEMIG Serviços S.A., vocês conseguiriam me recomendar alguma empresa de fornecimento de energia elétrica? A empresa… https://t.co/9S074ohcAx
# 1107138321044647938                                                                                                       ta faltando energia aqui Cemig \nbunita
# 1107145095013433344                                                                                            caiu a energia e vou dormir no valor, valeu Cemig.
# 1107338090975236097                                                                                     que maravilha ein cemig sem estar chovendo to sem energia
# 1107380419018797064                           Eu tô pensando é como vamos trabalhar na segunda pós sunsetville, mas tudo bem \nCemig vai ter que me dar energia 😂
#
#                            data
# id
# 1107125367767207936  2019-03-17
# 1107138321044647938  2019-03-17
# 1107145095013433344  2019-03-17
# 1107338090975236097  2019-03-17
# 1107380419018797064  2019-03-17

# %%
ax = sns.countplot(x="data", data=df_energia)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
df_tweets_tokens_pos[['text','data']].loc[df_tweets_tokens_pos['tokens'] == 'belo']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-14144d921ce3> in <module>()
# ----> 1 df_tweets_tokens_pos[['text']].loc[df_tweets_tokens_pos['tokens'] == 'belo']
#
# NameError: name 'df_tweets_tokens_pos' is not defined

# %%
df_tweets_tokens_pos[['text','data']].loc[df_tweets_tokens_pos['tokens'] == 'relevante']
# Out:
#                                                                                              text  \
# id
# 1109062517735731200  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/Dmem0VQzPH
# 1109062519933554688  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/e9lfnsZKRK
# 1109062601764495361  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/obDg5nb5IZ
# 1109062604159356928  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/90XArq3MG1
# 1109062646630887427  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/oKuGXbPsg7
# 1109062648824360960  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/iZ4s4HSdoF
# 1109062651659935745  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/BR7PbsRrD1
# 1109062654700720128  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/ZFMdkWKlQQ
# 1109062664175652865  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/DnSw6ViTl7
# 1109062668336418816  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/F9yV4fEGMX
# 1109062682903306240  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/sYjq9bUAt7
# 1109062684933271552  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/rjpdPgl9VX
# 1109062692449501184  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/bapd4YPxEA
# 1109062694504751105  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/hBPPkEqd2m
# 1109062942996221953  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/Rxo3HbTUyY
# 1109062953771388928  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/4zyV88ZklO
# 1109062959014313984  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/L1n5IImq5A
# 1109062965762949120  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/p6xKYN5CGZ
# 1109062970406039553  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/f0ZeIKd77X
# 1109062980082241537  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/JSCJgRaL8x
# 1109062985748754432  $CMIG4 - CEMIG (CMIG-N1) - Fato Relevante - 21/03/19 https://t.co/Rfyto4zfnH
#
#                            data
# id
# 1109062517735731200  2019-03-22
# 1109062519933554688  2019-03-22
# 1109062601764495361  2019-03-22
# 1109062604159356928  2019-03-22
# 1109062646630887427  2019-03-22
# 1109062648824360960  2019-03-22
# 1109062651659935745  2019-03-22
# 1109062654700720128  2019-03-22
# 1109062664175652865  2019-03-22
# 1109062668336418816  2019-03-22
# 1109062682903306240  2019-03-22
# 1109062684933271552  2019-03-22
# 1109062692449501184  2019-03-22
# 1109062694504751105  2019-03-22
# 1109062942996221953  2019-03-22
# 1109062953771388928  2019-03-22
# 1109062959014313984  2019-03-22
# 1109062965762949120  2019-03-22
# 1109062970406039553  2019-03-22
# 1109062980082241537  2019-03-22
# 1109062985748754432  2019-03-22

# %%
df_tweets_tokens_pos[['text','data']].loc[df_tweets_tokens_pos['tokens'] == 'energia']
# Out:
#                                                                                                                                                                 text  \
# id
# 1107125367767207936     CEMIG Serviços S.A., vocês conseguiriam me recomendar alguma empresa de fornecimento de energia elétrica? A empresa… https://t.co/9S074ohcAx
# 1107138321044647938                                                                                                          ta faltando energia aqui Cemig \nbunita
# 1107145095013433344                                                                                               caiu a energia e vou dormir no valor, valeu Cemig.
# 1107338090975236097                                                                                        que maravilha ein cemig sem estar chovendo to sem energia
# 1107380419018797064                              Eu tô pensando é como vamos trabalhar na segunda pós sunsetville, mas tudo bem \nCemig vai ter que me dar energia 😂
