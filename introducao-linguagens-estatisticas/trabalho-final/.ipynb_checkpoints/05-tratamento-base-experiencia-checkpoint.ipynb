# %% [markdown]
# # Trabalho Final
#
# **Aluno**: Carlos Alberto Rocha Cardoso
#
# **Matrícula**: 96983
#
#
#
# ## 05 - Tratamento da base *experiencia_trabalho.csv*
#
# Essa base descreve a experiência profissional dos funcionários, representados pela coluna chave **perfil_id**, apresentando a companhia (coluna **company**), localização (coluna **location**), o cargo (coluna **position**) e o período de início e término da experiência profissional (coluna **date**). Podem existir mais de um registro por **perfil_id**, no caso do funcionário possuir experiências profissionais diversas.
#
# Todos os 111 funcionários constam nessa base, porém o funcionário perfil_id = 108 não constará na base resultante do processo de tratamento e consolidação, uma vez que seu único registro de experiência não possui o período de início e término. Dessa forma 110 funcionários terão suas experiências profissionais consolidadas nas bases processadas.

# %%
import numpy as np
import pandas as pd
from unicodedata import normalize

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

experiencia = pd.read_csv("bases/experiencia_trabalho.csv")

# Análise inicial
print("Nº de registros:", len(experiencia))
print("Nº de valores únicos de perfil_id:", experiencia.perfil_id.nunique())
print("Nº de valores únicos de company:", experiencia.company.nunique())
print("Nº de valores únicos de location:", experiencia.location.nunique())
print("Nº de valores únicos de position:", experiencia.position.nunique())
print("Nº de valores vazios de company:", experiencia.company.isnull().sum())
print("Nº de valores vazios de date:", experiencia.date.isnull().sum())
print("Nº de valores vazios de location:", experiencia.location.isnull().sum())
print("Nº de valores vazios de position:", experiencia.position.isnull().sum())

experiencia.describe(include="all")

idx_perfis = experiencia.perfil_id
# Out:
# Nº de registros: 497
# Nº de valores únicos de perfil_id: 111
# Nº de valores únicos de company: 2
# Nº de valores únicos de location: 71
# Nº de valores únicos de position: 386
# Nº de valores vazios de company: 25
# Nº de valores vazios de date: 26
# Nº de valores vazios de location: 160
# Nº de valores vazios de position: 25

# %%
experiencia = experiencia[(experiencia.company.notnull()) & (experiencia.position.notnull()) & (experiencia.date.notnull())]
print("Nº de valores únicos de perfil_id:", experiencia.perfil_id.nunique())
print("Nº de registros restantes após remoção dos vazios:", len(experiencia))
print("Nº de valores vazios de company:", experiencia.company.isnull().sum())
print("Nº de valores vazios de date:", experiencia.date.isnull().sum())
print("Nº de valores vazios de location:", experiencia.location.isnull().sum())
print("Nº de valores vazios de position:", experiencia.position.isnull().sum())

print("\nNº de perfil_id excluídos por não possuírem valor de company ou position ou date:")
idx_perfis[~idx_perfis.isin(experiencia.perfil_id.unique())].values
# Out:
# Nº de valores únicos de perfil_id: 110
# Nº de registros restantes após remoção dos vazios: 471
# Nº de valores vazios de company: 0
# Nº de valores vazios de date: 0
# Nº de valores vazios de location: 134
# Nº de valores vazios de position: 0
#
# Nº de perfil_id excluídos por não possuírem valor de company ou position ou date:
# array([108], dtype=int64)

# %% [markdown]
# ## 05.1 - Tratamento das data
#
# A coluna **date** pode ser quebrada no ano de início (**inicio**) e no ano de fim (**fim**) da experiência. As experiências em aberto, possuem o texto "o momento" que será interpretado como o mês/ano da extração dos dados (09/2017). As experiências em aberto serão marcadas na coluna booleana **atual**, que indicando que o funcionário ainda trabalha na trojan.

# %%
experiencia.date = experiencia.date.str.replace('o momento','set de 2017')

ini_fim = experiencia.date.str.split('–')

experiencia['mesano_ini'] = ini_fim.str.get(0).str.strip()
experiencia['mesano_fim'] = ini_fim.str.get(1).str.strip()

#Cria a coluna atual para marcar apenas o emprego em aberto na empresa Trojan
experiencia['atual'] = (experiencia.mesano_fim.str.contains('set de 2017')) & (experiencia.company == 'Trojan Technologies')

#cria coluna para registrar o ano de inicio e fim do trabalho
experiencia['ano_ini'] = experiencia.mesano_ini.str.extract('(\d+)')
experiencia['ano_fim'] = experiencia.mesano_fim.str.extract('(\d+)')

# %% [markdown]
# A informação de duração da experiência (**duracao**) é derivada calculando a diferença do fim ao início em meses.

# %%
# calcula a duração estimada de cada experiência em meses
def format_mes(mes):
    mes = mes.str.replace('jan','01') \
                .str.replace('fev','02') \
                .str.replace('mar','03') \
                .str.replace('abr','04') \
                .str.replace('mai','05') \
                .str.replace('jun','06') \
                .str.replace('jul','07') \
                .str.replace('ago','08') \
                .str.replace('set','09') \
                .str.replace('out','10') \
                .str.replace('nov','11') \
                .str.replace('dez','12')
    return mes

experiencia.mesano_ini = format_mes(experiencia.mesano_ini)
experiencia.mesano_fim = format_mes(experiencia.mesano_fim)

experiencia.loc[(experiencia.mesano_ini.str.len() == 4), 'mesano_ini'] = '01 de '+experiencia.mesano_ini
experiencia.loc[(experiencia.mesano_fim.str.len() == 4), 'mesano_fim'] = '01 de '+experiencia.mesano_fim 

experiencia['d_ini'] = pd.to_datetime(experiencia.mesano_ini, format='%m de %Y')
experiencia['d_fim'] = pd.to_datetime(experiencia.mesano_fim, format='%m de %Y')

experiencia['duracao_meses'] = experiencia.d_fim.dt.to_period('M') - experiencia.d_ini.dt.to_period('M')+1

experiencia
# Out:
#                  company                       date  \
# 0    Trojan Technologies  set de 2011 – set de 2017
# 6            Any Company  mar de 2016 – set de 2017
# 7            Any Company  out de 2015 – set de 2017
# 8            Any Company  out de 2012 – mai de 2013
# 9            Any Company  set de 2009 – jan de 2011
# 10   Trojan Technologies  jul de 2017 – set de 2017
# 11           Any Company  jan de 2017 – set de 2017
# 12   Trojan Technologies  mar de 2017 – jul de 2017
# 13           Any Company  dez de 2016 – mar de 2017
# 14           Any Company  jun de 2016 – jan de 2017
# 15           Any Company  jul de 2017 – set de 2017
# 16   Trojan Technologies  nov de 2016 – set de 2017
# 17           Any Company  dez de 2015 – set de 2017
# 18           Any Company  abr de 2017 – jul de 2017
# 19           Any Company  ago de 2016 – fev de 2017
# 20   Trojan Technologies  ago de 2017 – set de 2017
# 21   Trojan Technologies  fev de 2017 – jul de 2017
# 23           Any Company  jul de 2016 – dez de 2016
# 24   Trojan Technologies  mar de 2017 – set de 2017
# 25   Trojan Technologies  fev de 2017 – fev de 2017
# 26   Trojan Technologies  jan de 2017 – jan de 2017
# 27   Trojan Technologies  jul de 2016 – dez de 2016
# 28           Any Company  mai de 2016 – jun de 2016
# 29   Trojan Technologies  jul de 2016 – set de 2017
# 30   Trojan Technologies  mai de 2015 – jun de 2016
# 31           Any Company  abr de 2012 – ago de 2015
# 32           Any Company  mar de 2011 – abr de 2012
# 33           Any Company  jun de 2008 – mar de 2011
# 34   Trojan Technologies  nov de 2016 – set de 2017
# 35   Trojan Technologies  nov de 2016 – set de 2017
# 36           Any Company  jul de 2005 – out de 2016
# 37           Any Company  set de 2002 – jul de 2005
# 38           Any Company  mai de 2001 – ago de 2002
# 39   Trojan Technologies  abr de 2017 – set de 2017
# 40           Any Company  out de 2015 – abr de 2017
# 41   Trojan Technologies  jan de 2011 – set de 2017
# 42           Any Company  mar de 2016 – set de 2017
# 43           Any Company  jan de 2017 – set de 2017
# 44           Any Company  out de 2015 – set de 2017
# 45           Any Company  out de 2012 – mai de 2013
# 46   Trojan Technologies  ago de 2016 – set de 2017
# 47   Trojan Technologies  set de 2014 – jul de 2016
# 48           Any Company  nov de 2010 – jul de 2012
# 49   Trojan Technologies  mai de 2017 – set de 2017
# 50   Trojan Technologies  jan de 2017 – abr de 2017
# 51   Trojan Technologies  dez de 2015 – jan de 2017
# 52   Trojan Technologies  abr de 2015 – dez de 2015
# 53           Any Company  jan de 2007 – abr de 2015
# 54   Trojan Technologies  set de 2017 – set de 2017
# 55   Trojan Technologies  jul de 2016 – set de 2017
# 56   Trojan Technologies  jan de 2016 – jun de 2016
# 57   Trojan Technologies  fev de 2015 – dez de 2015
# 58           Any Company  dez de 2014 – mar de 2015
# 59   Trojan Technologies  set de 2017 – set de 2017
# 60   Trojan Technologies  mar de 2017 – set de 2017
# 61   Trojan Technologies  mar de 2016 – mar de 2017
# 62           Any Company  jan de 2014 – jan de 2015
# 63           Any Company  fev de 2014 – ago de 2014
# 64   Trojan Technologies  ago de 2017 – set de 2017
# 65   Trojan Technologies  dez de 2016 – jul de 2017
# 66           Any Company  jul de 2016 – dez de 2016
# 67           Any Company  jan de 2016 – jul de 2016
# 68           Any Company  jun de 2015 – jan de 2016
# 69   Trojan Technologies  mai de 2017 – set de 2017
# 70   Trojan Technologies  jan de 2017 – mai de 2017
# 71   Trojan Technologies  ago de 2016 – dez de 2016
# 72           Any Company  jan de 2016 – jul de 2016
# 73           Any Company  mai de 2015 – dez de 2015
# 74   Trojan Technologies  mar de 2017 – set de 2017
# 75           Any Company  mar de 2015 – set de 2017
# 76           Any Company  jun de 2016 – mar de 2017
# 77           Any Company  out de 2013 – nov de 2014
# 78           Any Company  jul de 2013 – out de 2013
# 79   Trojan Technologies  set de 2017 – set de 2017
# 80   Trojan Technologies  mar de 2017 – ago de 2017
# 81           Any Company  out de 2015 – out de 2015
# 82           Any Company  jan de 2015 – jun de 2015
# 83           Any Company  jan de 2013 – dez de 2014
# 84   Trojan Technologies  ago de 2017 – set de 2017
# 85   Trojan Technologies  mar de 2017 – set de 2017
# 86           Any Company  set de 2014 – jul de 2015
# 87   Trojan Technologies  jul de 2017 – set de 2017
# 88   Trojan Technologies  abr de 2017 – jul de 2017
# 89           Any Company  mar de 2017 – jul de 2017
# 90   Trojan Technologies  out de 2016 – abr de 2017
# 91           Any Company  mar de 2016 – out de 2016
# 92   Trojan Technologies  mar de 2017 – set de 2017
# 93           Any Company  jan de 2016 – dez de 2016
# 94           Any Company  ago de 2014 – dez de 2016
# 95   Trojan Technologies  jan de 2017 – set de 2017
# 96           Any Company  dez de 2015 – set de 2017
# 97           Any Company  mar de 2015 – nov de 2015
# 98   Trojan Technologies  fev de 2017 – set de 2017
# 99           Any Company  ago de 2015 – out de 2016
# 100          Any Company  ago de 2014 – out de 2016
# 101          Any Company  out de 2014 – jul de 2015
# 102          Any Company  jul de 2011 – jun de 2014
# 103  Trojan Technologies  out de 2016 – set de 2017
# 104  Trojan Technologies  abr de 2015 – out de 2016
# 105          Any Company  set de 2014 – dez de 2014
# 106          Any Company  abr de 2012 – fev de 2014
# 107          Any Company  jul de 2011 – mar de 2012
# 108  Trojan Technologies  jan de 2017 – set de 2017
# 109          Any Company  mar de 2015 – mar de 2016
# 110          Any Company                2014 – 2016
# 111  Trojan Technologies  ago de 2016 – set de 2017
# 112          Any Company  nov de 2015 – jul de 2016
# 113          Any Company  ago de 2005 – fev de 2013
# 114  Trojan Technologies  jan de 2017 – set de 2017
# 115          Any Company  fev de 2016 – set de 2017
# 116          Any Company  ago de 2015 – set de 2017
# 118          Any Company  jan de 2012 – ago de 2012
# 119          Any Company  jan de 2011 – jan de 2012
# 120  Trojan Technologies  fev de 2017 – set de 2017
# 121          Any Company  jun de 2016 – jan de 2017
# 122  Trojan Technologies  mar de 2017 – set de 2017
# 123          Any Company  jul de 2016 – mar de 2017
# 124          Any Company  jan de 2016 – jul de 2016
# 125          Any Company  jul de 2015 – dez de 2015
# 126          Any Company  jul de 2015 – dez de 2015
# 127  Trojan Technologies  mai de 2017 – set de 2017
# 128  Trojan Technologies  fev de 2016 – abr de 2017
# 129          Any Company  ago de 2013 – jan de 2016
# 130          Any Company  mai de 2013 – jul de 2013
# 131          Any Company  jul de 2012 – dez de 2012
# 132  Trojan Technologies  out de 2016 – set de 2017
# 133          Any Company  jan de 2014 – out de 2016
# 134          Any Company  mar de 2012 – dez de 2013
# 135          Any Company  jan de 2010 – fev de 2012
# 136          Any Company  jan de 2005 – dez de 2009
# 137  Trojan Technologies  mar de 2017 – set de 2017
# 138  Trojan Technologies  jul de 2016 – set de 2017
# 139          Any Company  abr de 2014 – jun de 2016
# 140          Any Company  mar de 2010 – abr de 2014
# 141          Any Company  nov de 2007 – mar de 2010
# 142  Trojan Technologies  jul de 2017 – set de 2017
# 143  Trojan Technologies  fev de 2017 – set de 2017
# 145          Any Company  out de 2015 – set de 2016
# 146          Any Company  jun de 2012 – set de 2015
# 147          Any Company  mar de 2010 – jun de 2012
# 148  Trojan Technologies  out de 2013 – set de 2017
# 149          Any Company  jan de 2011 – jul de 2013
# 150          Any Company  fev de 2008 – jan de 2011
# 151          Any Company  abr de 2001 – jan de 2008
# 152          Any Company  jun de 2000 – jan de 2001
# 153  Trojan Technologies  jul de 2016 – set de 2017
# 154          Any Company  set de 2015 – mai de 2016
# 155          Any Company  out de 2013 – ago de 2015
# 156          Any Company  fev de 2010 – fev de 2011
# 157          Any Company  mar de 2009 – dez de 2009
# 158  Trojan Technologies  dez de 2012 – set de 2017
# 160          Any Company  mai de 2009 – dez de 2012
# 161          Any Company  mar de 2005 – out de 2010
# 162          Any Company  ago de 2008 – mar de 2009
# 163          Any Company  jan de 2008 – mai de 2008
# 164  Trojan Technologies  mar de 2017 – set de 2017
# 165          Any Company  ago de 2015 – jul de 2016
# 166          Any Company  jul de 2014 – jul de 2015
# 167  Trojan Technologies  jan de 2016 – set de 2017
# 168          Any Company  nov de 2013 – set de 2017
# 170          Any Company  nov de 2014 – jan de 2016
# 171          Any Company  mar de 2014 – dez de 2014
# 172          Any Company  jun de 2009 – dez de 2013
# 173  Trojan Technologies  mar de 2017 – set de 2017
# 174  Trojan Technologies  abr de 2015 – set de 2017
# 175          Any Company  fev de 2013 – mar de 2015
# 176          Any Company  dez de 2007 – jan de 2013
# 177  Trojan Technologies  out de 2016 – set de 2017
# 178          Any Company  mar de 2017 – set de 2017
# 179          Any Company  ago de 2012 – out de 2016
# 180          Any Company  jan de 2011 – abr de 2012
# 181          Any Company  jan de 2009 – dez de 2010
# 182  Trojan Technologies  mar de 2016 – set de 2017
# 183          Any Company  nov de 2014 – mar de 2016
# 184          Any Company  jul de 2014 – nov de 2014
# 185          Any Company  ago de 2014 – out de 2014
# 186          Any Company  jan de 2011 – dez de 2011
# 187  Trojan Technologies  jan de 2017 – set de 2017
# 188  Trojan Technologies  nov de 2015 – set de 2017
# 189          Any Company  mar de 2015 – mar de 2015
# 190          Any Company  mar de 2014 – out de 2014
# 191          Any Company  set de 2013 – mar de 2014
# 192  Trojan Technologies  jul de 2017 – set de 2017
# 193          Any Company  abr de 2014 – jul de 2016
# 194          Any Company  abr de 2012 – out de 2012
# 195  Trojan Technologies  out de 2016 – set de 2017
# 196          Any Company  dez de 2014 – out de 2016
# 197  Trojan Technologies  ago de 2017 – set de 2017
# 198          Any Company  nov de 2015 – mai de 2017
# 199          Any Company  jul de 2015 – nov de 2015
# 200          Any Company  jan de 2015 – jul de 2015
# 201          Any Company  out de 2014 – jan de 2015
# 202  Trojan Technologies  mai de 2017 – set de 2017
# 203  Trojan Technologies  out de 2016 – abr de 2017
# 204          Any Company  fev de 2016 – set de 2016
# 205          Any Company  jun de 2013 – jan de 2014
# 206  Trojan Technologies  out de 2016 – set de 2017
# 207  Trojan Technologies  out de 2016 – set de 2017
# 208          Any Company  abr de 2014 – abr de 2016
# 209          Any Company  fev de 2014 – mar de 2014
# 210          Any Company  ago de 2012 – fev de 2014
# 211  Trojan Technologies  jan de 2017 – set de 2017
# 213  Trojan Technologies  out de 2015 – dez de 2016
# 214          Any Company  out de 2014 – jun de 2015
# 215          Any Company  fev de 2012 – jul de 2014
# 216          Any Company  fev de 2010 – mai de 2012
# 217  Trojan Technologies  mar de 2015 – set de 2017
# 218          Any Company  ago de 2013 – mar de 2015
# 219          Any Company  mai de 2011 – jun de 2013
# 220          Any Company  mar de 2011 – fev de 2012
# 221          Any Company  jun de 2010 – mar de 2011
# 222  Trojan Technologies  jan de 2017 – set de 2017
# 223          Any Company  set de 2014 – jan de 2017
# 224          Any Company  jan de 2013 – set de 2014
# 225          Any Company  mar de 2012 – jan de 2013
# 226          Any Company  jun de 2010 – fev de 2012
# 227  Trojan Technologies  mar de 2015 – set de 2017
# 228          Any Company  fev de 2014 – dez de 2015
# 231  Trojan Technologies  jul de 2014 – mar de 2015
# 232          Any Company  abr de 2013 – jan de 2014
# 235          Any Company  set de 2012 – abr de 2013
# 236  Trojan Technologies  jul de 2017 – set de 2017
# 237  Trojan Technologies  ago de 2016 – jun de 2017
# 238          Any Company  dez de 2013 – ago de 2016
# 239          Any Company  jan de 2013 – jan de 2014
# 240          Any Company  nov de 2010 – mai de 2011
# 241          Any Company  ago de 2017 – set de 2017
# 242          Any Company  mai de 2017 – set de 2017
# 244  Trojan Technologies  jan de 2017 – set de 2017
# 245          Any Company  set de 2016 – set de 2017
# 246          Any Company  jun de 2016 – set de 2017
# 247  Trojan Technologies  abr de 2014 – set de 2017
# 249  Trojan Technologies  dez de 2013 – mar de 2014
# 250          Any Company  jun de 2012 – dez de 2013
# 251          Any Company  jan de 2011 – dez de 2011
# 252          Any Company  jan de 2009 – dez de 2010
# 253  Trojan Technologies  ago de 2017 – set de 2017
# 254  Trojan Technologies  fev de 2016 – ago de 2017
# 255          Any Company  jul de 2015 – jan de 2016
# 256          Any Company  dez de 2014 – out de 2015
# 257          Any Company  mar de 2015 – ago de 2015
# 258  Trojan Technologies  dez de 2016 – set de 2017
# 259          Any Company  fev de 2016 – jul de 2016
# 260          Any Company  jul de 2015 – dez de 2015
# 261  Trojan Technologies  mar de 2017 – set de 2017
# 262          Any Company  jul de 2016 – mar de 2017
# 263          Any Company  jun de 2016 – mar de 2017
# 264          Any Company  abr de 2016 – jun de 2016
# 265          Any Company  jun de 2015 – nov de 2015
# 266  Trojan Technologies  mar de 2017 – set de 2017
# 267          Any Company  mar de 2016 – mar de 2017
# 268          Any Company  set de 2013 – fev de 2016
# 269          Any Company  set de 2012 – set de 2013
# 270  Trojan Technologies  dez de 2016 – set de 2017
# 271          Any Company  jun de 2016 – dez de 2016
# 272          Any Company  mai de 2016 – dez de 2016
# 273          Any Company  dez de 2015 – jun de 2016
# 274          Any Company  jan de 2015 – jun de 2016
# 275  Trojan Technologies  mar de 2017 – set de 2017
# 276  Trojan Technologies  nov de 2012 – mar de 2017
# 277          Any Company  mar de 2009 – out de 2013
# 278          Any Company  dez de 2010 – dez de 2012
# 279          Any Company  out de 2010 – nov de 2012
# 280  Trojan Technologies  ago de 2016 – set de 2017
# 281          Any Company  jun de 2013 – jun de 2014
# 282          Any Company  set de 2013 – mai de 2014
# 283          Any Company  dez de 2012 – set de 2013
# 284  Trojan Technologies  jun de 2017 – set de 2017
# 285  Trojan Technologies  jun de 2014 – mai de 2017
# 286          Any Company  mai de 2014 – jun de 2014
# 287          Any Company  jul de 2012 – fev de 2014
# 288          Any Company  jan de 2012 – jun de 2012
# 289  Trojan Technologies  ago de 2017 – set de 2017
# 290          Any Company  abr de 2017 – ago de 2017
# 291          Any Company  jan de 2017 – jun de 2017
# 292          Any Company  jan de 2016 – jul de 2016
# 293          Any Company  nov de 2011 – dez de 2014
# 294  Trojan Technologies  mar de 2015 – set de 2017
# 295          Any Company  fev de 2012 – nov de 2014
# 296          Any Company  nov de 2011 – fev de 2012
# 297          Any Company  ago de 2011 – out de 2011
# 298          Any Company  mar de 2010 – dez de 2010
# 299  Trojan Technologies         2017 – set de 2017
# 300  Trojan Technologies  nov de 2014 – set de 2017
# 301          Any Company  set de 2013 – out de 2014
# 302  Trojan Technologies  nov de 2016 – set de 2017
# 303  Trojan Technologies  mar de 2017 – jul de 2017
# 304          Any Company  nov de 2015 – out de 2016
# 305          Any Company  ago de 2015 – out de 2016
# 306          Any Company  abr de 2013 – out de 2015
# 307  Trojan Technologies  out de 2014 – set de 2017
# 309  Trojan Technologies  nov de 2015 – set de 2017
# 310          Any Company                2014 – 2015
# 311          Any Company                2012 – 2014
# 312          Any Company  set de 2011 – fev de 2012
# 313          Any Company  jul de 2011 – ago de 2011
# 314  Trojan Technologies  jul de 2016 – set de 2017
# 315          Any Company  jan de 2016 – jun de 2016
# 316          Any Company  set de 2014 – dez de 2015
# 317          Any Company  dez de 2010 – nov de 2013
# 318          Any Company  jan de 2009 – dez de 2010
# 319  Trojan Technologies  jul de 2017 – set de 2017
# 320  Trojan Technologies  fev de 2017 – jul de 2017
# 321  Trojan Technologies  jun de 2016 – jan de 2017
# 323          Any Company  fev de 2017 – set de 2017
# 324  Trojan Technologies  nov de 2016 – set de 2017
# 325          Any Company  ago de 2016 – nov de 2016
# 326          Any Company  mar de 2015 – ago de 2016
# 327          Any Company  mar de 2015 – ago de 2016
# 328  Trojan Technologies  ago de 2015 – set de 2017
# 329          Any Company  fev de 2014 – ago de 2015
# 330          Any Company  ago de 2014 – mar de 2015
# 331          Any Company  out de 2013 – nov de 2014
# 332          Any Company  ago de 2012 – jan de 2014
# 333          Any Company  ago de 2017 – set de 2017
# 334  Trojan Technologies  out de 2016 – set de 2017
# 335  Trojan Technologies  mar de 2017 – set de 2017
# 336          Any Company  abr de 2016 – fev de 2017
# 338          Any Company  abr de 2013 – dez de 2015
# 341          Any Company  out de 2010 – mar de 2013
# 342          Any Company  mar de 2010 – out de 2010
# 343  Trojan Technologies  fev de 2017 – set de 2017
# 344          Any Company  abr de 2013 – set de 2017
# 345          Any Company  mai de 2012 – abr de 2013
# 346          Any Company  out de 2011 – jun de 2012
# 347          Any Company  jul de 2007 – set de 2011
# 348  Trojan Technologies  out de 2016 – set de 2017
# 349          Any Company  jun de 2015 – out de 2016
# 350  Trojan Technologies  mar de 2016 – set de 2017
# 351          Any Company  ago de 2014 – jan de 2016
# 352          Any Company  nov de 2011 – abr de 2014
# 353          Any Company  jan de 2011 – out de 2011
# 354  Trojan Technologies  out de 2016 – set de 2017
# 355          Any Company  abr de 2014 – set de 2016
# 356          Any Company  ago de 2012 – mar de 2014
# 357          Any Company  ago de 2008 – ago de 2012
# 358          Any Company  jul de 2003 – ago de 2008
# 359  Trojan Technologies  fev de 2017 – set de 2017
# 360          Any Company  out de 2014 – jan de 2017
# 361          Any Company  ago de 2010 – jan de 2017
# 362          Any Company  jan de 2013 – set de 2014
# 363          Any Company  jun de 2008 – jun de 2010
# 364  Trojan Technologies  out de 2016 – set de 2017
# 365          Any Company  fev de 2014 – mar de 2016
# 366          Any Company  dez de 2013 – fev de 2014
# 367          Any Company  mar de 2013 – nov de 2013
# 368          Any Company  set de 2012 – fev de 2013
# 369  Trojan Technologies  out de 2016 – set de 2017
# 370          Any Company  fev de 2016 – nov de 2016
# 371          Any Company  fev de 2016 – nov de 2016
# 372          Any Company  mai de 2014 – jun de 2015
# 373          Any Company  set de 2012 – mai de 2014
# 374  Trojan Technologies  jul de 2017 – set de 2017
# 375          Any Company  jan de 2017 – jun de 2017
# 376          Any Company  mai de 2016 – fev de 2017
# 377          Any Company  mar de 2015 – fev de 2016
# 378          Any Company  out de 2013 – mai de 2015
# 379  Trojan Technologies  fev de 2017 – set de 2017
# 380          Any Company  nov de 2016 – jan de 2017
# 381          Any Company  mar de 2013 – out de 2013
# 382  Trojan Technologies  out de 2016 – set de 2017
# 383          Any Company  abr de 2014 – jul de 2016
# 384          Any Company  dez de 2011 – mar de 2013
# 385  Trojan Technologies  abr de 2017 – set de 2017
# 386          Any Company  mar de 2015 – fev de 2016
# 387          Any Company  fev de 2014 – out de 2015
# 388          Any Company  fev de 2012 – fev de 2014
# 389  Trojan Technologies  out de 2016 – set de 2017
# 390          Any Company  abr de 2014 – abr de 2016
# 391          Any Company  ago de 2012 – mar de 2014
# 392          Any Company  abr de 2012 – ago de 2012
# 393          Any Company  jun de 2010 – mar de 2012
# 394  Trojan Technologies  out de 2016 – set de 2017
# 395  Trojan Technologies  out de 2016 – set de 2017
# 396          Any Company  out de 2015 – mar de 2016
# 397          Any Company  mar de 2013 – ago de 2013
# 398  Trojan Technologies  mar de 2017 – set de 2017
# 399          Any Company  dez de 2014 – jun de 2015
# 400          Any Company  nov de 2013 – dez de 2014
# 401  Trojan Technologies  mar de 2016 – set de 2017
# 402          Any Company  set de 2015 – fev de 2016
# 403          Any Company  set de 2014 – fev de 2016
# 404          Any Company  mai de 2013 – ago de 2014
# 405          Any Company  fev de 2011 – fev de 2013
# 406  Trojan Technologies  jun de 2017 – set de 2017
# 407          Any Company  nov de 2016 – jun de 2017
# 408          Any Company  abr de 2016 – nov de 2016
# 409          Any Company  jan de 2015 – abr de 2016
# 410          Any Company  mai de 2014 – jan de 2015
# 411  Trojan Technologies  ago de 2014 – set de 2017
# 412  Trojan Technologies  jan de 2014 – ago de 2014
# 413  Trojan Technologies  mar de 2013 – jan de 2014
# 414  Trojan Technologies  mar de 2017 – set de 2017
# 415          Any Company  fev de 2015 – mar de 2017
# 416          Any Company  nov de 2003 – jul de 2014
# 417          Any Company  mar de 2000 – nov de 2003
# 418  Trojan Technologies  abr de 2017 – set de 2017
# 419          Any Company  mar de 2013 – set de 2017
# 420          Any Company  fev de 2011 – fev de 2013
# 421          Any Company  jun de 2010 – jan de 2011
# 422          Any Company  jun de 2007 – jun de 2010
# 423  Trojan Technologies  ago de 2017 – set de 2017
# 424          Any Company  dez de 2016 – ago de 2017
# 425          Any Company  jan de 2015 – dez de 2016
# 426          Any Company  mar de 2014 – dez de 2014
# 427          Any Company  set de 2013 – fev de 2014
# 428  Trojan Technologies  jun de 2017 – set de 2017
# 429          Any Company  mai de 2017 – set de 2017
# 430          Any Company         2012 – set de 2017
# 431          Any Company         2010 – jun de 2013
# 432          Any Company         set de 2009 – 2013
# 433  Trojan Technologies  mar de 2017 – set de 2017
# 434          Any Company  fev de 2015 – mar de 2017
# 435          Any Company  dez de 2013 – jan de 2015
# 436          Any Company  abr de 2011 – dez de 2013
# 437          Any Company  jun de 2005 – jan de 2011
# 438  Trojan Technologies  mai de 2017 – set de 2017
# 439          Any Company  abr de 2017 – jul de 2017
# 440          Any Company         2016 – abr de 2017
# 441          Any Company                2016 – 2017
# 442          Any Company  dez de 2015 – ago de 2016
# 443  Trojan Technologies         2017 – set de 2017
# 444          Any Company  jan de 2011 – set de 2017
# 445          Any Company  abr de 2006 – abr de 2011
# 446          Any Company  mar de 2005 – mar de 2006
# 447          Any Company  out de 1996 – fev de 2005
# 448  Trojan Technologies  mar de 2017 – set de 2017
# 450          Any Company  jul de 2011 – set de 2017
# 452          Any Company  ago de 2015 – mar de 2017
# 454          Any Company  ago de 2013 – ago de 2015
# 455          Any Company  dez de 2012 – ago de 2013
# 456  Trojan Technologies  fev de 2017 – set de 2017
# 457          Any Company  set de 2015 – set de 2017
# 458          Any Company  out de 2013 – set de 2017
# 459          Any Company  ago de 2013 – nov de 2013
# 460          Any Company  jan de 2011 – set de 2013
# 461  Trojan Technologies  fev de 2017 – set de 2017
# 462          Any Company  jun de 2014 – fev de 2017
# 463          Any Company  jan de 2013 – out de 2014
# 464          Any Company  dez de 2008 – dez de 2012
# 465  Trojan Technologies         2017 – set de 2017
# 466          Any Company  mai de 2011 – mar de 2017
# 467          Any Company  out de 2010 – mai de 2011
# 468          Any Company  dez de 2005 – nov de 2010
# 469          Any Company  dez de 2008 – jul de 2009
# 470  Trojan Technologies  mar de 2017 – set de 2017
# 471          Any Company  ago de 2015 – ago de 2016
# 472          Any Company  mai de 2015 – ago de 2015
# 473          Any Company  abr de 2010 – mai de 2015
# 474          Any Company  jan de 2007 – mar de 2007
# 475  Trojan Technologies  jul de 2017 – set de 2017
# 476          Any Company  set de 2013 – jul de 2017
# 477          Any Company  abr de 2011 – ago de 2013
# 478          Any Company  nov de 2008 – mai de 2010
# 479          Any Company                2010 – 2010
# 480  Trojan Technologies  mar de 2017 – set de 2017
# 481          Any Company  jun de 2016 – fev de 2017
# 482          Any Company  jan de 2014 – jan de 2015
# 483          Any Company  mai de 2010 – mar de 2014
# 484          Any Company  mai de 2009 – mai de 2010
# 485  Trojan Technologies  jun de 2017 – set de 2017
# 486  Trojan Technologies  abr de 2017 – jun de 2017
# 487          Any Company  nov de 2016 – abr de 2017
09 de 2017   True    2017    2017 2017-03-01 2017-09-01             7
# 471  08 de 2016  False    2015    2016 2015-08-01 2016-08-01            13
# 472  08 de 2015  False    2015    2015 2015-05-01 2015-08-01             4
# 473  05 de 2015  False    2010    2015 2010-04-01 2015-05-01            62
# 474  03 de 2007  False    2007    2007 2007-01-01 2007-03-01             3
# 475  09 de 2017   True    2017    2017 2017-07-01 2017-09-01             3
# 476  07 de 2017  False    2013    2017 2013-09-01 2017-07-01            47
# 477  08 de 2013  False    2011    2013 2011-04-01 2013-08-01            29
# 478  05 de 2010  False    2008    2010 2008-11-01 2010-05-01            19
# 479  01 de 2010  False    2010    2010 2010-01-01 2010-01-01             1
# 480  09 de 2017   True    2017    2017 2017-03-01 2017-09-01             7
# 481  02 de 2017  False    2016    2017 2016-06-01 2017-02-01             9
# 482  01 de 2015  False    2014    2015 2014-01-01 2015-01-01            13
# 483  03 de 2014  False    2010    2014 2010-05-01 2014-03-01            47
# 484  05 de 2010  False    2009    2010 2009-05-01 2010-05-01            13
# 485  09 de 2017   True    2017    2017 2017-06-01 2017-09-01             4
# 486  06 de 2017  False    2017    2017 2017-04-01 2017-06-01             3
# 487  04 de 2017  False    2016    2017 2016-11-01 2017-04-01             6
# 488  06 de 2016  False    2015    2016 2015-10-01 2016-06-01             9
# 489  09 de 2015  False    2015    2015 2015-02-01 2015-09-01             8
# 491  09 de 2017   True    2017    2017 2017-03-01 2017-09-01             7
# 492  03 de 2017  False    2016    2017 2016-11-01 2017-03-01             5
# 493  11 de 2016  False    2016    2016 2016-01-01 2016-11-01            11
# 494  01 de 2016  False    2014    2016 2014-10-01 2016-01-01            16
# 495  10 de 2014  False    2013    2014 2013-06-01 2014-10-01            17
# 496  09 de 2017   True    2017    2017 2017-02-01 2017-09-01             8

# %% [markdown]
# Algumas informações consolidadas por funcionários podem ser extraídas dessa base. É possível extrair o tempo de carreira na empresa em meses (**tempo_empresa_meses**), o tempo de carreira no mercado em geral em meses (**tempo_mercado_meses**), e também a quantidade de empregos que o funcionário já teve (**qtd_empregos**), o que pode auxiliar em algo na análise. Portanto, obtenha essas informações.

# %%
# ----------- Cálculo do tempo_de_mercado_meses ------------ 
#     Os períodos de trabalho para um perfil não são subsequentes. Muitos períodos ocorrem simultaneamente.
#     Para cálculo do tempo de mercado foi utilizada uma estratégia de agrupar períodos sobrepostos em um mesmo período
#     contíno. Após esse agrupamento é realizado o cálculo de tempo de mercado para cada perfil

# Função utilizada para agrupar períodos contínuos e calcular o tempo de mercado em cada período
def calc_t_mercado_periodo(x):
     return pd.Series(dict(
                             perfil_id = x['perfil_id'].min(),
                             d_ini = x['d_ini'].min(), 
                             d_fim = x['d_fim'].max(),
                             tempo_meses = x['d_fim'].max().to_period('M') - x['d_ini'].min().to_period('M') +1
                          )
                     )
    
def calculo_meses(df):
#instancia dataframe que receberá os períodos de trabalho agrupados 
    g_periodos = pd.DataFrame()

#itera sobre cada perfil
    for key, p in df.groupby('perfil_id'):
        p = p.reset_index()

#itera sobre os periodos e verifica se o proximo periodo é sobreposto ao grupo de periodo anterior
#se não for registra, a data que sera usada para agrupar os periodos anteriores que sao sobrepostos 
        fim_grupo = p.loc[0, 'd_fim']
        for l in range(len(p)-1):
            if fim_grupo < p.loc[l+1, 'd_ini']:
                p.loc[l, 'grupo'] = p.loc[l, 'd_fim']

#se a data fim do periodo é maior que a data fim do proximo, mantem a data para comparacao       
            if fim_grupo < p.loc[l+1, 'd_fim']:
                fim_grupo = p.loc[l+1, 'd_fim']

#replica a mesma data final para todos os periodos que são sobrepostos
        l = p.tail(1).index
        p.loc[l,'grupo'] =  p.loc[l,'d_fim']
        p['grupo'] = p.grupo.fillna(method='backfill')

#agrupa os periodos e calcula o tempo de mercado para cada grupo de periodo
        p = p.groupby(['perfil_id','grupo'], as_index=False).apply(calc_t_mercado_periodo)
#adiciona periodos agrupados no dataframe
        g_periodos = pd.concat([g_periodos, p], ignore_index=True)
        
    return g_periodos

# %%
#calcula tempo total de mercado por perfil
tempo_mercado = experiencia[['perfil_id','d_ini','d_fim']].sort_values(by=['perfil_id','d_ini'])
tempo_mercado = calculo_meses(tempo_mercado)
tempo_mercado = tempo_mercado.groupby('perfil_id', as_index=False).agg({'tempo_meses':'sum'})
tempo_mercado = tempo_mercado.rename(index=int, columns={'tempo_meses':'tempo_mercado_meses'})

tempo_mercado = tempo_mercado.set_index('perfil_id')

#Confirma valores únicos de perfil_id para tempo de mercado
print("Nº de valores únicos de perfil_id:", tempo_mercado.index.nunique())
tempo_mercado.head(5)
# Out:
# Nº de valores únicos de perfil_id: 110
#            tempo_mercado_meses
# perfil_id
# 0                           90
# 1                           16
# 2                           22
# 3                           14
# 4                           17

# %%
#calcula tempo_empresa_meses
tempo_empresa = experiencia.loc[(experiencia.company == 'Trojan Technologies'), ['perfil_id','d_ini','d_fim']].sort_values(by=['perfil_id','d_ini'])
tempo_empresa = calculo_meses(tempo_empresa)
tempo_empresa = tempo_empresa.groupby('perfil_id', as_index=False).agg({'tempo_meses':'sum'})
tempo_empresa = tempo_empresa.rename(index=int, columns={'tempo_meses':'tempo_empresa_meses'})

tempo_empresa = tempo_empresa.set_index('perfil_id')

#Confirma valores únicos de perfil_id para tempo de empresa
print("Nº de valores únicos de perfil_id:", tempo_empresa.index.nunique())
tempo_empresa.head(5)
# Out:
# Nº de valores únicos de perfil_id: 110
#            tempo_empresa_meses
# perfil_id
# 0                           73
# 1                            7
# 2                           11
# 3                            8
# 4                           15

# %%
#calcula quantidade de empregos
qtd_empregos = experiencia.groupby(['perfil_id']).position.count().to_frame()
qtd_empregos = qtd_empregos.rename(index=int, columns={'position':'qtd_empregos'})

#Confirma valores únicos de perfil_id para quantidade de empregos
print("Nº de valores únicos de perfil_id:", qtd_empregos.index.nunique())
qtd_empregos.head(5)
# Out:
# Nº de valores únicos de perfil_id: 110
#            qtd_empregos
# perfil_id
# 0                     5
# 1                     5
# 2                     5
# 3                     3
# 4                     5

# %% [markdown]
# ## 05.2 - Cargo atual na empresa

# %%
#Funcao para 
def consolida_cargo_atual(df):
    return pd.Series(dict(
                        data_admissao = df['d_ini'].min(),
                        posicao_atual = ' | '.join(df['position'])
                    )
    )
    
# Alguns perfis acumulam mais de uma posicao atualmente na empresa
# foi utilizada uma funcao lambda para concatenar as posicoes acumulados em uma mesma linha do perfil
cargo_atual = experiencia.loc[experiencia.atual] \
                        .groupby(['perfil_id']) \
                        .apply(consolida_cargo_atual)
cargo_atual = cargo_atual.reset_index()

#Formata data_admissao para ano/mes
cargo_atual['data_admissao'] = cargo_atual['data_admissao'].dt.strftime("%Y-%m")

#Confirma valores únicos de perfil_id para o cargo atual na empresa
print("Nº de valores únicos de perfil_id:", cargo_atual.index.nunique())
cargo_atual.head(7)
# Out:
# Nº de valores únicos de perfil_id: 110
#    perfil_id data_admissao                                      posicao_atual
# 0          0       2011-09                                    CEO and Founder
# 1          1       2017-07                                    Product Manager
# 2          2       2016-11                               Full Stack Developer
# 3          3       2017-08                                        CRM Analyst
# 4          4       2017-03                       Sales Operations Coordinator
# 5          5       2016-07                                Key Account Manager
# 6          6       2016-11  Software Engineer and Data Scientist | Data En...

# %% [markdown]
# ## 05.3 - Setor do Funcionário na empresa
#
# A partir da posicao dos funcionários, é possível descobrir (ou inferir) o setor que eles trabalham.

# %%
#Quantidade de valores únicos de cargos atuais na empresa
print("Nº de valores únicos de cargo_atual:",cargo_atual.posicao_atual.nunique())
# Out:
# Nº de valores únicos de cargo_atual: 96

# %%
#Tratando os cargos para mesmo padrão: sem acentos, sem espaços, caixa alta
def remove_acentos(text):
    return normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')

cargo_atual['posicao_atual'] = cargo_atual.posicao_atual.apply(remove_acentos)
cargo_atual['posicao_atual'] = cargo_atual.posicao_atual.str.strip()
cargo_atual['posicao_atual'] = cargo_atual.posicao_atual.str.upper()


#Quantidade de valores únicos de cargos após tratamento
print("Nº de valores únicos de cargo_atual:",cargo_atual.posicao_atual.nunique())
# Out:
# Nº de valores únicos de cargo_atual: 94

# %%
#exportando dados de cargo atual para inserir as informações de setor
#a análise dos cargos, definição e inserção do departamento será feita em planilha eletrônica
cargos = cargo_atual.groupby('posicao_atual').posicao_atual.count().to_frame()
cargos.to_csv('bases/cargos.csv')

# %%
#Ao analisar as posições na empresa, encontramos posições de HEAD
#Dessa forma inferimos os 9 departamentos da empresa, utilizados para classificar as posições 
cargos[cargos.posicao_atual.index.str.contains('HEAD')]
# Out:
#                                       posicao_atual
# posicao_atual
# HEAD OF COMMERCIAL                                1
# HEAD OF CUSTOMER SUCCESS                          1
# HEAD OF DATA ANALYTICS                            1
# HEAD OF IN-STORE OPERATION                        1
# HEAD OF PEOPLE                                    1
# HEAD OF PRODUCT DESIGN - UXP                      1
# HEAD OF SALES                                     1
# HEAD OF STRATEGY                                  1
# HEAD OF TROJAN TECHNOLOGIES IN-STORE              1

# %%
#após edição dos dados em planilha eletrônica, esses são os departamentos atribuídos à cada posição
cargos_departamentos = pd.read_csv("bases/cargos-departamentos.csv")
cargos_departamentos.head(5)
# Out:
#                           posicao_atual  posicao_atual.1  \
# 0               ANALISTA DE ATENDIMENTO                1
# 1             ANALISTA DE CONTROLADORIA                1
# 2                        ANALISTA DE DP                2
# 3                 ANALISTA DE MARKETING                1
# 4  ANALISTA DE TECNOLOGIA DA INFORMACAO                1
#
#                    departamento
# 0              CUSTOMER SUCCESS
# 1                      STRATEGY
# 2                        PEOPLE
# 3                         SALES
# 4  TROJAN TECHNOLOGIES IN-STORE

# %%
cargo_atual_departamento = pd.merge(cargo_atual, cargos_departamentos[['posicao_atual','departamento']], how='left', on=['posicao_atual'])
cargo_atual_departamento = cargo_atual_departamento.set_index('perfil_id')
cargo_atual_departamento
# Out:
#           data_admissao                                      posicao_atual  \
# perfil_id
# 0               2011-09                                    CEO AND FOUNDER
# 1               2017-07                                    PRODUCT MANAGER
# 2               2016-11                               FULL STACK DEVELOPER
# 3               2017-08                                        CRM ANALYST
# 4               2017-03                       SALES OPERATIONS COORDINATOR
# 5               2016-07                                KEY ACCOUNT MANAGER
# 6               2016-11  SOFTWARE ENGINEER AND DATA SCIENTIST | DATA EN...
# 7               2017-04                             APREDIZ ADMINISTRATIVO
# 8               2011-01                                    FOUNDER AND CFO
# 9               2016-08                           SALES OPERATIONS MANAGER
# 10              2017-05                         HEAD OF IN-STORE OPERATION
# 11              2016-07            PEOPLE CONSULTANT | KEY ACCOUNT MANAGER
# 12              2017-03                   OPERACOES ERP | TIME DE EXPANSAO
# 13              2017-08                                  ESTAGIARIA DE CRM
# 14              2017-05                                    PRODUCT MANAGER
# 15              2017-03                                        KEY ACCOUNT
# 16              2017-09                                     HEAD OF PEOPLE
# 17              2017-03  PUBLIC RELATIONS INTERN | CUSTOMER SUCCESS INTERN
# 18              2017-07                            TRADE MARKETING ANALYST
# 19              2017-03                          CUSTOMER SUCCESS - INTERN
# 20              2017-01                                   TIME DE EXPANSAO
# 21              2017-02                             ONBOARDING COORDINATOR
# 22              2016-10                                     ANALISTA DE DP
# 23              2017-01                                   DIRETORA DE ARTE
# 24              2016-08                             ENGENHEIRO DE SOFTWARE
# 25              2017-01                                   COSTOMER SUCCESS
# 26              2017-02                            CUSTOMER SUCESS ANALYST
# 27              2017-03                     ESTAGIARIA DE CUSTOMER SUCCESS
# 28              2017-05                           COORDENADORA DE BRANDING
# 29              2016-10                            LEAD SOFTWARE DEVELOPER
# 30              2017-03                                   CUSTOMER SUCCESS
# 31              2016-07                                FULL STACK ENGINEER
# 32              2017-02     KEY ACCOUNT MANAGER | BUSINESS SALES EXECUTIVE
# 33              2013-10                     LEAD PRODUCT DESIGNER, PARTNER
# 34              2016-07                                    PRODUCT MANAGER
# 35              2012-12                      ENGENHEIRO DE SOFTWARE SENIOR
# 36              2017-03                                   CUSTOMER SUCCESS
# 37              2016-01                                 SOFTWARE DEVELOPER
# 38              2015-04     ARQUITETO DE SOLUCOES | ENGENHEIRO DE SOFTWARE
# 39              2016-10             BUSINESS INTELLIGENCE AND DATA ANALYST
# 40              2016-03                                        TECH LEADER
# 41              2015-11       ANALISTA FINANCEIRO | ESTAGIARIA DE FINANCAS
# 42              2017-07                                ANALISTA FINANCEIRO
# 43              2016-10                          ANALISTA DE CONTROLADORIA
# 44              2017-08                                 SOFTWARE ARCHITECT
# 45              2017-05                               DESENVOLVEDOR JUNIOR
# 46              2016-10                                 SOFTWARE DEVELOPER
# 47              2016-10                                 TALENT ACQUISITION
# 48              2017-01  GESTORA DO TIME DE PESSOAS - RESPONSAVEL POR R...
# 49              2015-03                                 SENIOR UX DESIGNER
# 50              2017-01                              DIRECTOR OF MARKETING
# 51              2015-03                                                COO
# 52              2017-07                             PRODUCT GROWTH MANAGER
# 53              2017-01                                  CREATIVE DESIGNER
# 54              2014-04                           HEAD OF CUSTOMER SUCCESS
# 55              2017-08                                 PURCHASING ANALYST
# 56              2016-12                           ESTAGIO EM MARKETING CRM
# 57              2017-03                                 COORDENADORA DE CS
# 58              2017-03                                     ANALISTA DE DP
# 59              2016-12                           ESTAGIARIA DO FINANCEIRO
# 60              2017-03                             HEAD OF DATA ANALYTICS
# 61              2016-08                                 COMMERCIAL ANALYST
# 62              2017-06                                 HEAD OF COMMERCIAL
# 63              2017-08               ANALISTA DE TECNOLOGIA DA INFORMACAO
# 64              2015-03                                ANALISTA FINANCEIRO
# 65              2014-11          PEOPLE CONSULTANT | PROGRAMADOR FRONT END
# 66              2016-11                       BUSINESS DEVELOPMENT MANAGER
# 67              2014-10                                   CUSTOMER SUCCESS
# 68              2015-11               HEAD OF TROJAN TECHNOLOGIES IN-STORE
# 69              2016-07                                    TRADE MARKETING
# 70              2017-07                           SALES OPERATIONS ANALYST
# 71              2016-11                            ESTAGIARIA DE MARKETING
# 72              2015-08                           COORDENADOR DE MARKETING
# 73              2016-10                                  ANDROID DEVELOPER
# 74              2017-03                                         COMMERCIAL
# 75              2017-02                               GERENTE DE OPERACOES
# 76              2016-10                                    TRADE MARKETING
# 77              2016-03                                KEY ACCOUNT MANAGER
# 78              2016-10                       HEAD OF PRODUCT DESIGN - UXP
# 79              2017-02                            LEAD SOFTWARE DEVELOPER
# 80              2016-10                         SOFTWARE TEST DEVELOPER II
# 81              2016-10                                   FINANCE DIRECTOR
# 82              2017-07                                   DESENVOLVEDOR JR
# 83              2017-02                               DESENVOLVEDOR JUNIOR
# 84              2016-10                              DESENVOLVEDOR PLENO I
# 85              2017-04                                      IOS DEVELOPER
# 86              2016-10                                 SOFTWARE DEVELOPER
# 87              2016-10                         DESENVOLVEDORA DE SOFTWARE
# 88              2016-10                                 SOFTWARE DEVELOPER
# 89              2017-03                             TIME DE EXPANSAO LOCAL
# 90              2016-03                  DATA ENGINEER BI AND DATA ANALYST
# 91              2017-06           ESPECIALISTA EM MARKETING DE PERFORMANCE
# 92              2014-08                            ANALISTA DE ATENDIMENTO
# 93              2017-03                                EXECUTIVO DE VENDAS
# 94              2017-04                                      HEAD OF SALES
# 95              2017-08                                   HEAD OF STRATEGY
# 96              2017-06               BUSINESS DEVELOPER + PRODUCT MANAGER
# 97              2017-03                         EXECUTIVO COMERCIAL SENIOR
# 98              2017-05                                       INSIDE SALES
# 99              2017-01                    GERENTE REGIONAL RIO DE JANEIRO
# 100             2017-03                              COORDENADOR COMERCIAL
# 101             2017-02                        GERENTE COMERCIAL SAO PAULO
# 102             2017-02                                EXECUTIVA DE CONTAS
# 103             2017-01  GERENTE COMERCIAL E OPERACOES REGIONAL CENTRO-...
# 104             2017-03                                    SALES EXECUTIVE
# 105             2017-07                                 SOFTWARE ARCHITECT
# 106             2017-03                                EXECUTIVO DE VENDAS
# 107             2017-06                              ANALISTA DE MARKETING
# 109             2017-03                               GERENTE REGIONAL SUL
# 110             2017-02                                 SOFTWARE DEVELOPER
#
#                            departamento
# perfil_id
# 0                              STRATEGY
# 1          TROJAN TECHNOLOGIES IN-STORE
# 2          TROJAN TECHNOLOGIES IN-STORE
# 3                      CUSTOMER SUCCESS
# 4                                 SALES
# 5                      CUSTOMER SUCCESS
# 6                        DATA ANALYTICS
# 7                              STRATEGY
# 8                              STRATEGY
# 9                                 SALES
# 10                   IN-STORE OPERATION
# 11                     CUSTOMER SUCCESS
# 12                   IN-STORE OPERATION
# 13                     CUSTOMER SUCCESS
# 14         TROJAN TECHNOLOGIES IN-STORE
# 15                     CUSTOMER SUCCESS
# 16                               PEOPLE
# 17                     CUSTOMER SUCCESS
# 18                                SALES
# 19                     CUSTOMER SUCCESS
# 20                   IN-STORE OPERATION
# 21                   IN-STORE OPERATION
# 22                               PEOPLE
# 23                 PRODUCT DESIGN - UXP
# 24         TROJAN TECHNOLOGIES IN-STORE
# 25                     CUSTOMER SUCCESS
# 26                     CUSTOMER SUCCESS
# 27                     CUSTOMER SUCCESS
# 28                             STRATEGY
# 29         TROJAN TECHNOLOGIES IN-STORE
# 30                     CUSTOMER SUCCESS
# 31         TROJAN TECHNOLOGIES IN-STORE
# 32                                SALES
# 33                 PRODUCT DESIGN - UXP
# 34         TROJAN TECHNOLOGIES IN-STORE
# 35         TROJAN TECHNOLOGIES IN-STORE
# 36                     CUSTOMER SUCCESS
# 37         TROJAN TECHNOLOGIES IN-STORE
# 38         TROJAN TECHNOLOGIES IN-STORE
# 39                       DATA ANALYTICS
# 40         TROJAN TECHNOLOGIES IN-STORE
# 41                             STRATEGY
# 42                             STRATEGY
# 43                             STRATEGY
# 44         TROJAN TECHNOLOGIES IN-STORE
# 45         TROJAN TECHNOLOGIES IN-STORE
# 46         TROJAN TECHNOLOGIES IN-STORE
# 47                               PEOPLE
# 48                               PEOPLE
# 49                 PRODUCT DESIGN - UXP
# 50                                SALES
# 51                                SALES
# 52         TROJAN TECHNOLOGIES IN-STORE
# 53                 PRODUCT DESIGN - UXP
# 54                     CUSTOMER SUCCESS
# 55                   IN-STORE OPERATION
# 56                                SALES
# 57                     CUSTOMER SUCCESS
# 58                               PEOPLE
# 59                             STRATEGY
# 60                       DATA ANALYTICS
# 61                           COMMERCIAL
# 62                           COMMERCIAL
# 63         TROJAN TECHNOLOGIES IN-STORE
# 64                             STRATEGY
# 65         TROJAN TECHNOLOGIES IN-STORE
# 66                             STRATEGY
# 67                     CUSTOMER SUCCESS
# 68         TROJAN TECHNOLOGIES IN-STORE
# 69                                SALES
# 70                                SALES
# 71                                SALES
# 72                                SALES
# 73         TROJAN TECHNOLOGIES IN-STORE
# 74                           COMMERCIAL
# 75                           COMMERCIAL
# 76                                SALES
# 77                     CUSTOMER SUCCESS
# 78                 PRODUCT DESIGN - UXP
# 79         TROJAN TECHNOLOGIES IN-STORE
# 80         TROJAN TECHNOLOGIES IN-STORE
# 81                             STRATEGY
# 82         TROJAN TECHNOLOGIES IN-STORE
# 83         TROJAN TECHNOLOGIES IN-STORE
# 84         TROJAN TECHNOLOGIES IN-STORE
# 85         TROJAN TECHNOLOGIES IN-STORE
# 86         TROJAN TECHNOLOGIES IN-STORE
# 87         TROJAN TECHNOLOGIES IN-STORE
# 88         TROJAN TECHNOLOGIES IN-STORE
# 89                   IN-STORE OPERATION
# 90                       DATA ANALYTICS
# 91                                SALES
# 92                     CUSTOMER SUCCESS
# 93                                SALES
# 94                                SALES
# 95                             STRATEGY
# 96         TROJAN TECHNOLOGIES IN-STORE
# 97                           COMMERCIAL
# 98                                SALES
# 99                           COMMERCIAL
# 100                          COMMERCIAL
# 101                          COMMERCIAL
# 102                    CUSTOMER SUCCESS
# 103                          COMMERCIAL
# 104                               SALES
# 105        TROJAN TECHNOLOGIES IN-STORE
# 106                               SALES
# 107                               SALES
# 109                          COMMERCIAL
# 110        TROJAN TECHNOLOGIES IN-STORE

# %%
#Confirma valores únicos de perfil_id para o cargo atual na empresa
print("Nº de valores únicos de perfil_id:", cargo_atual_departamento.index.nunique())
cargo_atual_departamento.head(5)
# Out:
# Nº de valores únicos de perfil_id: 110
#           data_admissao                 posicao_atual  \
# perfil_id
# 0               2011-09               CEO AND FOUNDER
# 1               2017-07               PRODUCT MANAGER
# 2               2016-11          FULL STACK DEVELOPER
# 3               2017-08                   CRM ANALYST
# 4               2017-03  SALES OPERATIONS COORDINATOR
#
#                            departamento
# perfil_id
# 0                              STRATEGY
# 1          TROJAN TECHNOLOGIES IN-STORE
# 2          TROJAN TECHNOLOGIES IN-STORE
# 3                      CUSTOMER SUCCESS
# 4                                 SALES

# %% [markdown]
# ## 05.4 Salvando Base Tratada
#
# A base tratada será gravada no arquivo **experiencia_trabalho-tratado.csv**.
#
# As informações consolidadas por perfil serão gravadas na base **perfil-experiencia,csv** contendo as colunas: **perfil_id**, **posicao_atual**, **data_admissao**, **departamento**, **tempo_empresa_meses**, **tempo_mercado_meses**, **qtd_empregos**.

# %%
# Grava experiencia_trabalho-tratado.csv
experiencia.to_csv('bases/experiencia_trabalho-tratado.csv')

# %%
# Grava  perfil-experiencia.csv
perfil_experiencia = pd.concat([cargo_atual_departamento, tempo_empresa, tempo_mercado, qtd_empregos], axis=1, sort=False)
perfil_experiencia.to_csv('bases/perfil-experiencia.csv')

# %% [markdown]
# ### Navegação:
# * [Voltar para a análise](00-analise-dos-dados.ipynb)
