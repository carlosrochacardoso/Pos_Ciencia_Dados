# %% [markdown]
# # Trabalho Final
#
# **Aluno**:
#
# **Matrícula**:
#
#
# ## 03 - Tratamento da base *formacao.csv*
#
# Descreve a base aqui com suas palavras.

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

formacao = pd.read_csv("bases/formacao.csv")

# Análise inicial da qualidade dessa base
print("Quantidade de registros: ", len(formacao))
print("Quantidade de valores distintos de perfil_id: ", formacao.perfil_id.nunique())
print("Dados faltantes em degree: ", len(formacao.loc[formacao.degree.isnull()]))
print("Dados faltantes em date: ", len(formacao.loc[formacao.date.isnull()]))
print("Dados faltantes em major: ", len(formacao.loc[formacao.major.isnull()]))
print("Dados faltantes em school: ", len(formacao.loc[formacao.school.isnull()]))
print("Dados faltantes em degree + major: ", len(formacao.loc[(formacao.degree.isnull()) & (formacao.major.isnull())]))
print("Dados faltantes em degree + major + school: ", len(formacao.loc[(formacao.degree.isnull()) & (formacao.major.isnull()) & (formacao.school.isnull())]))
print("Valores distintos em degree: ", len(formacao.groupby('degree').nunique()))
print("Valores distintos em major: ", len(formacao.groupby('major').nunique()))
print("Valores distintos em school: ", len(formacao.groupby('school').nunique()))
# Out:
# Quantidade de registros:  220
# Quantidade de valores distintos de perfil_id:  111
# Dados faltantes em degree:  29
# Dados faltantes em date:  7
# Dados faltantes em major:  50
# Dados faltantes em school:  1
# Dados faltantes em degree + major:  13
# Dados faltantes em degree + major + school:  1
# Valores distintos em degree:  135
# Valores distintos em major:  114
# Valores distintos em school:  122

# %%
formacao.head(5)
# Out:
#           date                                             degree  \
# 0  2016 – 2016  Nome do diploma\r\nExecutive Education, Innova...
# 1  2007 – 2010                       Nome do diploma\r\nEconomics
# 2  2015 – 2015  Nome do diploma\r\nMaster of Business Administ...
# 3  2009 – 2012  Nome do diploma\r\nBacharel em Design de Ambie...
# 4  2016 – 2019               Nome do diploma\r\nBachelor’s Degree
#
#                                                major  \
# 0                                                NaN
# 1                        Área de estudo\r\nEconomics
# 2               Área de estudo\r\nGestão de Negócios
# 3             Área de estudo\r\nDesign de Interiores
# 4  Área de estudo\r\nComputer Technology/Computer...
#
#                                    school  perfil_id
# 0                     Stanford University          0
# 1    Universidade Federal de Minas Gerais          0
# 2       Centro Universitário Newton Paiva          1
# 3  Universidade do Estado de Minas Gerais          1
# 4    Universidade Federal de Minas Gerais          2

# %% [markdown]
# ## 03.1 - Tratamento das datas
#
# Um primeiro tratamento feito será o de data. A coluna **date** que indica o íncio e o fim do curso e será quebrada em duas colunas numéricas (**inicio** e **fim**), e ainda numa terceira coluna indicando a duração estimada do curso em anos baseado na informação obtida (**duracao**).

# %%
inicio_termino = formacao.date.str.split('–')

formacao['inicio'] = pd.to_numeric(inicio_termino.str.get(0))
formacao['termino'] = pd.to_numeric(inicio_termino.str.get(1))
formacao['duracao'] = (formacao['termino'] - formacao['inicio']) + 1

# %% [markdown]
# ## 03.2 - Tratamento da coluna de grau de escolaridade
#
# Uma vez que a coluna **degree** não é muito precisa, uma coluna **grau** será criada. Ela começará vazia e será armazenado a inferência do grau de formação baseado na análise das demais colunas.
#
# Uma primeira estratégia será avaliar o nome do **degree** para inferir se ele contém algum fragmento que possa indicar algum dos seguintes graus de escolaridade, representados por números: **Ensino Médio**=1, **Técnico**=2, **Superior**=3 ou **Pós-Graduação**=4.
#
# Para isso, utilize a função [`contains`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.contains.html).

# %%
formacao.degree.unique()
# Out:
# array(['Nome do diploma\r\nExecutive Education, Innovation & Entrepreneurship',
#        'Nome do diploma\r\nEconomics',
#        'Nome do diploma\r\nMaster of Business Administration (MBA)',
#        'Nome do diploma\r\nBacharel em Design de Ambientes',
#        'Nome do diploma\r\nBachelor’s Degree',
#        'Nome do diploma\r\nTechnician',
#        'Nome do diploma\r\nEngenharia de Produção Civil',
#        'Nome do diploma\r\nBachelor of Science (B.S.)',
#        'Nome do diploma\r\nPós Graduação em Gestão Estratégica de Negócios',
#        'Nome do diploma\r\nBacharel em Publicidade e Propaganda',
#        "Nome do diploma\r\nMaster's Degree",
#        'Nome do diploma\r\nCursando administração', nan,
#        'Nome do diploma\r\nBacharel',
#        'Nome do diploma\r\nBacharelado em Engenharia',
#        'Nome do diploma\r\nTécnico',
#        'Nome do diploma\r\nComunicação Social - Publicidade e Propaganda',
#        'Nome do diploma\r\nEnsino Médio',
#        'Nome do diploma\r\nGraduação em Engenharia',
#        "Nome do diploma\r\nBachelor's Degree",
#        'Nome do diploma\r\nBusiness Specialist',
#        'Nome do diploma\r\nAdministração em Comércio Exterior',
#        'Nome do diploma\r\nBacharelado em Administração',
#        'Nome do diploma\r\nBacharel em Ciências Econômicas',
#        "Nome do diploma\r\nBachelor's degree",
#        'Nome do diploma\r\nStudy Abroad',
#        'Nome do diploma\r\nMaster of Business Administration - MBA',
#        'Nome do diploma\r\nBacharelado em Comunicação Social ênfase em Relações Públicas',
#        'Nome do diploma\r\nCiências Econômicas',
#        'Nome do diploma\r\nEnsino Primário ao Ensino Médio',
#        'Nome do diploma\r\nLoyola Intensive English Program - Summer 2014',
#        'Nome do diploma\r\nBacharel - Publicidade e Propaganda',
#        'Nome do diploma\r\nEnsino médio', 'Nome do diploma\r\nMestrado',
#        'Nome do diploma\r\nBacharelado',
#        'Nome do diploma\r\nBacharelado em Comunicação Social, Publicidade e Propaganda',
#        'Nome do diploma\r\nBacharelado em Comunicação Social - Publicidade e Propaganda',
#        'Nome do diploma\r\nBacharel, jornalismo',
#        'Nome do diploma\r\nBachelor of Comunication',
#        'Nome do diploma\r\nMasters', 'Nome do diploma\r\nCollege',
#        'Nome do diploma\r\nBachelor', 'Nome do diploma\r\nTechnical',
#        'Nome do diploma\r\n2011', 'Nome do diploma\r\nPost-graduate',
#        'Nome do diploma\r\nHigh School / Technical School',
#        'Nome do diploma\r\nMaster of Science (MSc)',
#        'Nome do diploma\r\nBachelor of Science (B.Sc.)',
#        'Nome do diploma\r\nMaster',
#        'Nome do diploma\r\nBachelor of Industrial Engineering',
#        'Nome do diploma\r\nMinor, International Financial Management',
#        'Nome do diploma\r\nMinor, Business Process Integration Management',
#        'Nome do diploma\r\nBacharel em Sistemas de Informação',
#        'Nome do diploma\r\nGraduação em Sistemas de Informação',
#        'Nome do diploma\r\nPós Graduação em Ciência de Dados e Big Data',
#        'Nome do diploma\r\nMBA em Consultoria Organizacional',
#        'Nome do diploma\r\nEspecialista em Gastronomia (Cozinheiro profissional)',
#        'Nome do diploma\r\nPós Graduação em Design de Interação',
#        'Nome do diploma\r\nCurso tecnico',
#        'Nome do diploma\r\nBachelor of Business Administration (B.B.A.)',
#        'Nome do diploma\r\nTurismo e Lazer',
#        'Nome do diploma\r\nEspecialização',
#        'Nome do diploma\r\nCiências Econômicas com Ênfase em Controladoria',
#        'Nome do diploma\r\nTechnologist in',
#        'Nome do diploma\r\nBacharelado em Sistemas de Informação',
#        'Nome do diploma\r\nTécnico em Informática',
#        'Nome do diploma\r\nNon-degree Student',
#        'Nome do diploma\r\nInterniship', 'Nome do diploma\r\nPsicologia',
#        'Nome do diploma\r\nPsicóloga', 'Nome do diploma\r\nPós-graduação',
#        'Nome do diploma\r\nPós-Graduação',
#        'Nome do diploma\r\nEspecialista',
#        'Nome do diploma\r\nEngenharia da Computação',
#        'Nome do diploma\r\nAdministracao de Empresas',
#        'Nome do diploma\r\nbacharelado',
#        'Nome do diploma\r\nBachelor of Business Administration (BBA)',
#        'Nome do diploma\r\nBacharel em Publicidade',
#        'Nome do diploma\r\nEnsino Médio e Técnico em Eletrônica',
#        'Nome do diploma\r\nTecnólogo em Analise e Desenvolvimento de Sistemas',
#        'Nome do diploma\r\nHelp Desk', 'Nome do diploma\r\nGraduate',
#        'Nome do diploma\r\nUnder Graduate',
#        'Nome do diploma\r\nMarketing Estratégico',
#        'Nome do diploma\r\nPublicidade e Propaganda',
#        'Nome do diploma\r\nSistemas de Informação',
#        'Nome do diploma\r\nInternational Business Management',
#        'Nome do diploma\r\nPós em Engenharia de Sotware',
#        'Nome do diploma\r\nLicenciatura em História',
#        'Nome do diploma\r\nPós Graduação',
#        'Nome do diploma\r\nPeople Management Specialization',
#        'Nome do diploma\r\nGraduação',
#        'Nome do diploma\r\nPós-Graduação em Comunicação Digital',
#        'Nome do diploma\r\nBachelor of Science (B.S.), Economics',
#        'Nome do diploma\r\nTecnico',
#        'Nome do diploma\r\nBacharel em Propaganda e Marketing',
#        'Nome do diploma\r\nGraduação em Filmmaking',
#        'Nome do diploma\r\nMBA Latu Sensu',
#        'Nome do diploma\r\nMarketing',
#        'Nome do diploma\r\nGoogle AdWords Fundamentals',
#        'Nome do diploma\r\nAnalise Google Analytics',
#        "Nome do diploma\r\nMaster's degree",
#        'Nome do diploma\r\nB.S. in Computer Science',
#        'Nome do diploma\r\nBacharel em Engenharia da Computação',
#        'Nome do diploma\r\nSpecialization: Computation Statistics and Data Analysis',
#        'Nome do diploma\r\nbacharelado em Sistemas de Informação',
#        'Nome do diploma\r\nTécnico de Nível médio integrado em informática',
#        'Nome do diploma\r\nBacharelado em Ciência da Computação',
#        'Nome do diploma\r\nEnsino Médio Integrado ao Técnico',
#        'Nome do diploma\r\nEngenheiro de Computação',
#        'Nome do diploma\r\nMaster in Informatics',
#        'Nome do diploma\r\nTechnologist in Data Processing',
#        'Nome do diploma\r\nInterchange Student',
#        'Nome do diploma\r\nTécnico em processamento de dados.',
#        'Nome do diploma\r\nEngenharia e Administração de Banco de Dados, Especialização',
#        'Nome do diploma\r\nPós-Graduado',
#        'Nome do diploma\r\nBacharel em Comunicação Social Integrada',
#        'Nome do diploma\r\nProcessos Gerenciais',
#        'Nome do diploma\r\nCiência da Computação',
#        'Nome do diploma\r\nGestão de vendas e Negociação',
#        'Nome do diploma\r\nHigh School',
#        'Nome do diploma\r\nMarketing Digital',
#        'Nome do diploma\r\nComercio exterior',
#        'Nome do diploma\r\nMaster en ingénierie',
#        'Nome do diploma\r\nMBA',
#        'Nome do diploma\r\nGraduação em Comunicação Social',
#        'Nome do diploma\r\nMBA EM COMUNICAÇÃO E MARKETING',
#        'Nome do diploma\r\nAnalise e Desenvolvimento de Sistemas',
#        'Nome do diploma\r\nBacharelado em Administração de Empresas',
#        'Nome do diploma\r\nBacharel em Administração de Empresas',
#        'Nome do diploma\r\nMaster’s Degree',
#        'Nome do diploma\r\nBachelor of Engineering (B.E.)',
#        'Nome do diploma\r\nBacherelando',
#        'Nome do diploma\r\nGestão Comercial',
#        'Nome do diploma\r\nMarketing Digital e Publicidade On Line',
#        'Nome do diploma\r\nAnalista de Sistemas'], dtype=object)

# %%
formacao['grau'] = formacao['degree']

formacao.grau = formacao.grau.str.replace("Nome do diploma\r\n", "")

# Troca os valores não informados de proficiência por "Não informado"
formacao.grau.fillna("Não informado", inplace=True)
formacao.school.fillna("Não informado", inplace=True)

formacao.loc[formacao.grau.str.contains("Médio", case=False), "grau"] = "1"
formacao.loc[formacao.grau.str.contains("High School", case=False), "grau"] = "1"

formacao.loc[formacao.grau.str.contains("Tec", case=False), "grau"] = "2"
formacao.loc[formacao.grau.str.contains("Téc", case=False), "grau"] = "2"
formacao.loc[formacao.grau.str.contains("Help Desk", case=False), "grau"] = "2"
formacao.loc[formacao.grau.str.contains("Turismo", case=False), "grau"] = "2"
formacao.loc[formacao.grau.str.contains("Google AdWords Fundamentals", case=False), "grau"] = "2"
formacao.loc[formacao.grau.str.contains("English Program", case=False), "grau"] = "2"

formacao.loc[formacao.grau.str.contains("Bach", case=False), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("B.S.", case=False, regex=False), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Enge", case=False, regex=True), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Graduação", case=False, regex=True), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Analis", case=False, regex=True), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Ciência", case=False, regex=True), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Admin", case=False), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Psic[ó,o]l", case=False), "grau"] = "3"
formacao.loc[formacao.grau.str.contains("^Cursando administração", case=False), "grau"] = "3"

formacao.loc[formacao.grau.str.contains("MBA", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Master", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Mestrado", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Speci", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("P[ó,o]s", case=False, regex=True), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Executive", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Minor", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("International Business Management", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Interniship", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Gestão de vendas e Negociação", case=False), "grau"] = "4"
formacao.loc[formacao.grau.str.contains("Processos Gerenciais", case=False), "grau"] = "4"



formacao.grau.unique()
# Out:
# array(['4', 'Economics', '3', '2', 'Não informado',
#        'Comunicação Social - Publicidade e Propaganda', '1',
#        'Study Abroad', 'College', '2011', 'Non-degree Student',
#        'Graduate', 'Under Graduate', 'Marketing Estratégico',
#        'Publicidade e Propaganda', 'Sistemas de Informação',
#        'Licenciatura em História', 'Marketing', 'Interchange Student',
#        'Marketing Digital', 'Comercio exterior', 'Gestão Comercial',
#        'Marketing Digital e Publicidade On Line'], dtype=object)

# %% [markdown]
# Para os demais casos do grau de escolaridade não cobertos pela análise do texto, deverá ser feita uma análise mais profunda. Tente encontrar outros padrões para definir o grau de escolaridade, por exemplo, o nome da instituição de ensino (campo **school**) ou, então, o tempo de duração.

# %%
formacao.loc[formacao.school.str.contains("^Col[e,é]gio", case=False, regex=True), "grau"] = "1"
formacao.loc[formacao.school.str.contains("Marista", case=False, regex=True), "grau"] = "1"
formacao.loc[formacao.school.str.contains("^Loyola", case=False, regex=True) 
             & (formacao.duracao > 5), "grau"] = "1"

formacao.loc[formacao.school.str.contains("Udacity", case=False, regex=True), "grau"] = "2"
formacao.loc[formacao.school.str.contains("Ecommerce School", case=False), "grau"] = "2"
formacao.loc[formacao.school.str.contains("Claudio Torres", case=False), "grau"] = "2"

formacao.loc[(formacao.duracao > 2)
             & (formacao.grau.str.len() > 1)
             & (formacao.school.str.contains("Uni|Fed", case=False)), 'grau'] = "3"

formacao.loc[(formacao.duracao <= 2)
             & (formacao.grau.str.len() > 1)
             & (formacao.school.str.contains("Uni|Fed", case=False)), 'grau'] = "4"
#formacao.loc[formacao.school.str.contains("IEC", case=False, regex=True), "grau"] = "4"
formacao.loc[(formacao.duracao == 1)
             & (formacao.grau.str.len() > 1)
             & (formacao.school.str.contains("Stanford", case=False)), 'grau'] = "4"

#formacao.loc[formacao.school.str.contains("^Loyola", case=False, regex=True)]

# %% [markdown]
# ## 03.3 - Tratamento da coluna de grau de escolaridade
#
# A coluna **school** apresenta uma vasta de gama de categorias. Porém numa análise visual dos seus diferentes valores é possível ver que algumas instituições de ensino apresentam variações de nome. Foi feita uma substituição para agrupar esses casos num único nome. O resultao do tratamento é armazenado na nova coluna **instituicao**.

# %%
formacao['instituicao'] = formacao['school']

print(formacao.instituicao)
# Out:
# 0                                    Stanford University
# 1                   Universidade Federal de Minas Gerais
# 2                      Centro Universitário Newton Paiva
# 3                 Universidade do Estado de Minas Gerais
# 4                   Universidade Federal de Minas Gerais
# 5                   Universidade Federal de Minas Gerais
# 6      Centro Federal de Educação Tecnológica de Mina...
# 7                   Universidade Federal de Minas Gerais
# 8                 California State University-Long Beach
# 9                                     Universidade FUMEC
# 10                                                Uni-BH
# 11                  Universidade Federal de Minas Gerais
# 12                                                  FEAD
# 13                                   Stanford University
# 14           UFMG - Universidade Federal de Minas Gerais
# 15                                    Universidade FUMEC
# 16                Centro Universitário de Belo Horizonte
# 17      Pontifícia Universidade Católica de Minas Gerais
# 18      Pontifícia Universidade Católica de Minas Gerais
# 19                                               COTEMIG
# 20                  Universidade Federal de Minas Gerais
# 21                               Colégio Santo Agostinho
# 22                  Universidade Federal de Minas Gerais
# 23                                 Colégio Santo Antônio
# 24                  Universidade Federal de Minas Gerais
# 25           UFMG - Universidade Federal de Minas Gerais
# 26                             Business Training Company
# 27                              Centro Universitário UNA
# 28     Graduação em Administração em Comércio Exterio...
# 29                        Universidade Federal de Viçosa
# 30                               Fundacao Getulio Vargas
# 31                            University of West Florida
# 32                Universidade do Estado de Minas Gerais
# 33                                University of Limerick
# 34                                                 Ibmec
# 35                  Universidade Federal de Minas Gerais
# 36                Centro Universitário de Belo Horizonte
# 37      Pontifícia Universidade Católica de Minas Gerais
# 38                               Colégio Santo Agostinho
# 39                         Loyola University New Orleans
# 40                                    Universidade FUMEC
# 41                Centro Universitário de Belo Horizonte
# 42                Centro Universitário de Belo Horizonte
# 43             Escola Estadual Presidente Tancredo Neves
# 44                  Universidade Federal de Minas Gerais
# 45                  Universidade Federal de Minas Gerais
# 46                  Universidade Federal de Minas Gerais
# 47     Centro Federal de Educação Tecnológica de Mina...
# 48                  Universidade Federal de Minas Gerais
# 49      Pontifícia Universidade Católica de Minas Gerais
# 50                  Universidade Federal de Minas Gerais
# 51           UFMG - Universidade Federal de Minas Gerais
# 52                                 Universidade do Porto
# 53           UFMG - Universidade Federal de Minas Gerais
# 54                        Federal University of Amazonas
# 55                        Federal University of Amazonas
# 56                             Colegio Militar de Manaus
# 57                  Universidade Federal de Minas Gerais
# 58                  Universidade Federal de Juiz de Fora
# 59     Instituto Federal de Educação, Ciência e Tecno...
# 60                            Universidade Estácio de Sá
# 61      Pontifícia Universidade Católica de Minas Gerais
# 62                          Escola de Engenharia Kennedy
# 63                                    Colégio Brasileiro
# 64                    Universidade Federal de Pernambuco
# 65                    Universidade Federal de Pernambuco
# 66                                          andre guedes
# 67                  Universidade Federal de Minas Gerais
# 68                  Universidade Federal de Minas Gerais
# 69                  Universidade Federal de Minas Gerais
# 70                              Hogeschool van Amsterdam
# 71                              Hogeschool van Amsterdam
# 72                                       Colégio Cotemig
# 73        Faculdade Católica Salesiana do Espírito Santo
# 74      Pontifícia Universidade Católica de Minas Gerais
# 75                              Centro Universitário UNA
# 76                IGA - Instituto gastronomico argentino
# 77      Pontifícia Universidade Católica de Minas Gerais
# 78                  Universidade Federal de Minas Gerais
# 79                               Fundação Getulio Vargas
# 80                               Bridge Business College
# 81     Centro Federal de Educação Tecnológica de Mina...
# 82     Centro Federal de Educação Tecnológica de Mina...
# 83      Pontifícia Universidade Católica de Minas Gerais
# 84                       Universidade Federal de Alfenas
# 85                       Universidade Federal de Alfenas
# 86                                   Faculdade Pitágoras
# 87                      Universidade Federal do Amazonas
# 88     IFAM - Instituto Federal de Educação, Ciência ...
# 89                      Universidade Federal do Amazonas
# 90                                 Kent State University
# 91                    The Catholic University of America
# 92                  Universidade Federal de Minas Gerais
# 93                                 Colegio Santo Antônio
# 94                Universidade Federal de Santa Catarina
# 95            UNINTER Centro Universitário Internacional
# 96                      Escola Brasileira de Psicanálise
# 97      Pontifícia Universidade Católica de Minas Gerais
# 98           Instituto de Estudos Superiores da Amazônia
# 99                               Fundação Getulio Vargas
# 100                      Universidade Federal Fluminense
# 101                 Universidade Federal de Minas Gerais
# 102                                              Marista
# 103                                            PUC Minas
# 104                                      Colégio COTEMIG
# 105                                                 ETFG
# 106                 Universidade Federal de Minas Gerais
# 107                        Universidade Vale do Rio Doce
# 108                 Universidade Federal de Minas Gerais
# 109                                 Colégio Piracicabano
# 110                 Universidade Federal de Minas Gerais
# 111    Colégio Técnico Industrial - Prof. Isaac Porta...
# 112                                    Faculdade Cotemig
# 113                    Centro Universitário Newton Paiva
# 114                     Universidade Salgado de Oliveira
# 115                                             SENAC MG
# 116                 Universidade Federal de Minas Gerais
# 117                              Colégio Santo Agostinho
# 118     Pontifícia Universidade Católica de Minas Gerais
# 119                 Universidade Federal de Minas Gerais
# 120                 Universidade Federal de Minas Gerais
# 121                            University of Connecticut
# 122     IEC - Instituto de Educação Continuada PUC Minas
# 123     Pontifícia Universidade Católica de Minas Gerais
# 124                           Universidade Estácio de Sá
# 125    Caldwell Community College and Technical Insti...
# 126                           ÚNICA - Escola de Negócios
# 127                 Universidade Federal de Minas Gerais
# 128                                Faculdade Senac Minas
# 129     Pontifícia Universidade Católica de Minas Gerais
# 130                 Universidade Federal de Juiz de Fora
# 131                          Universidade Cândido Mendes
# 132      Centro Universitário de Belo Horizonte - UNI-BH
# 133     Pontifícia Universidade Católica de Minas Gerais
# 134               Centro Universitário de Belo Horizonte
# 135                              Fundação Getulio Vargas
# 136                                               Loyola
# 137                                Universidade Paulista
# 138                             Centro Universitário UNA
# 139                                              Polimig
# 140                 Universidade Federal de Minas Gerais
# 141                 Universidade Federal de Minas Gerais
# 142                                               Facamp
# 143                     Academia Internacional de Cinema
# 144                     Universidade Federal do Amazonas
# 145        Pontifícia Universidade Católica de São Paulo
# 146                                        Não informado
# 147                                   Universidade FUMEC
# 148                                  Faculdade Pitágoras
# 149    Instituto Federal de Educação, Ciência e Tecno...
# 150                       Universidade Vale do Rio Verde
# 151                          Universidade de Santo Amaro
# 152                                                 Gawa
# 153                                                 Gawa
# 154                 Universidade Presbiteriana Mackenzie
# 155                     Universidade Federal do Amazonas
# 156                                     Faculdade FUCAPI
# 157                     Universidade Federal do Amazonas
# 158                 Universidade Federal de Juiz de Fora
# 159                 Universidade Federal de Juiz de Fora
# 160                       Universidade da Beira Interior
# 161                     Universidade Fereral do Amazonas
# 162    Instituto Federal de Educação, Ciência e Tecno...
# 163                                                 Ufam
# 164                             Fundacao Nokia de Ensino
# 165             Universidade do Estado do Amazonas - UEA
# 166                                               Fucapi
# 167                Federal University of Amazonas - UFAM
# 168                      Amazonas State University - UEA
# 169                     Universidade Federal do Amazonas
# 170                              University of Stuttgart
# 171                              University of Stuttgart
# 172                     Universidade Federal do Amazonas
# 173                                       Fundação Nokia
# 174                 Universidade Federal de Minas Gerais
# 175                 Universidade Federal de Minas Gerais
# 176     Pontifícia Universidade Católica de Minas Gerais
# 177                                   Colégio Brasileiro
# 178          UNICAMP - Universidade Estadual de Campinas
# 179               Centro Universitário de Belo Horizonte
# 180     Pontifícia Universidade Católica de Minas Gerais
# 181     Pontifícia Universidade Católica de Minas Gerais
# 182                                        Estácio de Sá
# 183                              Universidade de Alfenas
# 184            FIA - Fundação Instituto de Administração
# 185        Pontifícia Universidade Católica de São Paulo
# 186                                     Ecommerce School
# 187          UFMG - Universidade Federal de Minas Gerais
# 188                                Universidade do Porto
# 189                          CSA | Colégio Santo Antônio
# 190                                               PUC-SP
# 191                                               PUC-SP
# 192                                    Lourenço Castanho
# 193                                       Udacity Brasil
# 194                           Universidade do Grande ABC
# 195              Centro Universitário da Grande Dourados
# 196    Centro Federal de Educação Tecnológica de Mina...
# 197                     Université catholique de Louvain
# 198                               Cedepe Business School
# 199         Esurp - Escola Superior de Relações Públicas
# 200         Esurp - Escola Superior de Relações Públicas
# 201                         Universidade Cruzeiro do Sul
# 202                         Universidade Cruzeiro do Sul
# 203                                Universidade Paulista
# 204                         Universidade Paulista / UNIP
# 205                               Anhanguera Educacional
# 206                    Universidade Católica de Brasília
# 207                                   UNICEUB - Brasília
# 208                Nova School of Business and Economics
# 209                                               Insper
# 210                 Universidade Presbiteriana Mackenzie
# 211                  Instituto de Ensino Superior Fucapi
# 212                         Universidade Anhembi Morumbi
# 213                   Centro Universitário Nove de Julho
# 214                            Faculdade de direito UFPR
# 215                    Marketing Digital- Claudio Torres
# 216                                                 FTEC
# 217    PUCRS - Pontifícia Universidade Católica do Ri...
# 218                     Universidade Federal do Amazonas
# 219    Instituto Federal de Educação, Ciência e Tecno...
# Name: instituicao, dtype: object

# %% [markdown]
# ## 03.4 - Área de Formação
#
# Agrupe as formações em grupos mais macros, por exemplo: Engenharia de Alimento, Engharia Elétrica estariam no grupo de engenharias, já Ciência da Computação, Sistemas de Informação poderiam estar no grupo de T.I. Crie áreas que façam sentido, agrupe os dados criando uma nova coluna no dataframe chamada area.

# %% [markdown]
# ## 03.5 - Escolaridade
#
# Uma informação consolidada de cada funcionário que pode ser derivada dessa base é a sua escolaridade (**escolaridade**), que é pode ser obtida pegando o maio grau daquele perfil. Gere uma base à parte contendo essa informação.

# %% [markdown]
# ## 03.6 Salvando Base Tratada
#
# A base tratada será gravada no arquivo **formacao-tratado.csv**.
#
# A base consolidadada com uma informação por registro será gravada no arquivo **perfil-formacao.csv** contendo as colunas: **perfil_id**, **escolaridade**, **escolaridade_numero**, **area**, **duracao**.

# %%
# Grava a formação tratada em arquivo
formacao_tratado.to_csv('bases/formacao-tratado.csv')

# Grava o consolidade da formação por perfil em arquivo
formacao_perfil = pd.concat([escolaridade, area], axis=1)
formacao_perfil.to_csv('bases/perfil-formacao.csv')

# %% [markdown]
# ### Navegação:
# * [Voltar para a análise](00-analise-dos-dados.ipynb)
# * [Continuar para o próximo documento](04-tratamento-base-habilidades.ipynb)
